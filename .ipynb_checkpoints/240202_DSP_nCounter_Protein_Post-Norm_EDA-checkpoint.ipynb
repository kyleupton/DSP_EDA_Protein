# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import scipy
from scipy import stats as stats
from copy import copy as copy

from openpyxl import load_workbook
from openpyxl.worksheet.table import Table
# import seaborn as sns

# %%
writeOutput = False

# %%
os.getcwd()
# Out:
# '/Users/upton6/Library/CloudStorage/OneDrive-QueenslandUniversityofTechnology/Documents/notebooks/Nanostring/Adams_Bray/DSP_EDA_Protein'

# %%
# read in paths from config file
configDict = {
    'rootDir': '',
    'initialDataPath' : '',
    'QCDataPath' : '',
    'labWorksheet01Path':'',
    'sampleInfoFile' : '',
    'projectName':'',
}

with open('./config.txt','r') as f:
    lines = f.readlines()
    for line in lines:
        if not line.startswith('#'):
            line = line.strip()
            fields = line.split(':')

            if fields[0].strip()=='initialDataPath':
                configDict[fields[0].strip()] = fields[1].strip().strip('\'')
            else:
                configDict[fields[0].strip()] = fields[1].strip().strip('\'')
## ToDo: Add checks to ensure that minimal fields have been populated. Raise errors or warnings

# %%
configDict
# Out:
# {'rootDir': '/Users/upton6/Documents/Nanostring/projects/Adams/',
#  'initialDataPath': 'Initial Dataset.xlsx',
#  'QCDataPath': 'Default_QC.xlsx',
#  'labWorksheet01Path': 'Lab_Worksheet_P1001660017100A.txt',
#  'sampleInfoFile': 'sampleInfo_with_Wells.csv',
#  'projectName': 'Adams_Bray'}

# %% [markdown]
# # Define functions

# %%
# Functinos have been moved out to .py files.

# %% [markdown]
# # Run Analysis

# %%
# ToDo:
# add sample info file details into config file in previous notebook
# sampleInfo_with_Wells.csv

# %%
# ToDo: Should initial filtering be done using none-mean-HKGeoMean normalised data. Using a type of background subtraction for filtering would bias towards removing noisy or low expressing samples. Removing these may give more accurate estimates of real probe values.

# %%
sampleInfo = pd.read_csv(os.path.join(configDict['rootDir'], configDict['sampleInfoFile']), index_col=0)

# %%
sampleInfo
# Out:
#                                                         TMA_001_TNBC_240327a_001_Segment 1  \
# Custom Segment Name                                 TMA_001_TNBC_240327a | 001 | Segment 1
# ROI                                                   1c2ab061-972b-4227-95e9-5258d51c8e27
# ROI (Label)                                                                            001
# Segment                                               7936d809-ce05-4697-b1fd-f78adfeed555
# Segment (Name/ Label)                                                            Segment 1
# ROI X Coordinate                                                          15998.4228515625
# ROI Y Coordinate                                                                 47604.875
# Segment Tags                                                                     Segment 1
# AOI                                                                                      1
# AOI surface area                                                                      8341
# AOI nuclei count                                                                       111
# Fov count                                                                              555
# Fov counted                                                                            543
# BindingDensity                                                                         0.2
# Scan Name                                                             TMA_001_TNBC_240327a
# Slide                                                 28915c3d-c3ae-4cad-a109-774962c18b57
# Scan plexset                                                                             2
# Origin Instrument ID                                                             2001G0086
# #Factor                                                                                NaN
# Sample_Type                                                                        primary
# Patient                                                                      2011A19876_1O
# Scan_ID                                                               TMA_001_TNBC_240327a
# Broad_classification                                                               Primary
# ROI_ID                                                                                 001
# LOT_Human_Immune_Cell_Profiling_Protein_Core_1_1                                 ICPH10007
# LOT_Human_Immune_Activation_Status_Protein_Modu...                               IASH10003
# LOT_Human_Immune_Cell_Typing_Protein_Module_1_0                                   ICTH1006
# LOT_Human_Pan_Tumor_Protein_Module_1_0                                           PTRH10001
# LOT_Human_IO_Drug_Target_Protein_Module_1_1                                      DRGH10003
# LOT_Human_PI3K_AKT_Signaling_Protein_Module_1_0                                  PKSH10002
# LOT_Human_nC_Cell_Death_Protein_1_2                                              CLDH10001
# Well                                                                                   A01
# Row                                                                                      A
# Col                                                                                     01
# Plate                                                                                    1
#
#                                                         TMA_001_TNBC_240327a_002_Segment 1  \
# Custom Segment Name                                 TMA_001_TNBC_240327a | 002 | Segment 1
# ROI                                                   b465b231-4735-4036-96b5-51b75b387433
# ROI (Label)                                                                            002
# Segment                                               0a7b8f61-078d-4877-9053-b53e5fd4614d
# Segment (Name/ Label)                                                            Segment 1
# ROI X Coordinate                                                           17548.470703125
# ROI Y Coordinate                                                              42694.140625
# Segment Tags                                                                     Segment 1
# AOI                                                                                      1
# AOI surface area                                                                     25360
# AOI nuclei count                                                                       164
# Fov count                                                                              555
# Fov counted                                                                            548
# BindingDensity                                                                        0.14
# Scan Name                                                             TMA_001_TNBC_240327a
# Slide                                                 28915c3d-c3ae-4cad-a109-774962c18b57
# Scan plexset                                                                             2
# Origin Instrument ID                                                             2001G0086
# #Factor                                                                                NaN
# Sample_Type                                                                           node
# Patient                                                                      2011A19876_5B
# Scan_ID                                                               TMA_001_TNBC_240327a
# Broad_classification                                                             Secondary
# ROI_ID                                                                                 002
# LOT_Human_Immune_Cell_Profiling_Protein_Core_1_1                                 ICPH10007
# LOT_Human_Immune_Activation_Status_Protein_Modu...                               IASH10003
# LOT_Human_Immune_Cell_Typing_Protein_Module_1_0                                   ICTH1006
# LOT_Human_Pan_Tumor_Protein_Module_1_0                                           PTRH10001
# LOT_Human_IO_Drug_Target_Protein_Module_1_1                                      DRGH10003
# LOT_Human_PI3K_AKT_Signaling_Protein_Module_1_0                                  PKSH10002
# LOT_Human_nC_Cell_Death_Protein_1_2                                              CLDH10001
# Well                                                                                   A02
# Row                                                                                      A
# Col                                                                                     02
# Plate                                                                                    1
#
#                                                         TMA_001_TNBC_240327a_003_Segment 1  \
# Custom Segment Name                                 TMA_001_TNBC_240327a | 003 | Segment 1
# ROI                                                   208ede3e-c633-4f23-aa77-98412fc80c33
# ROI (Label)                                                                            003
# Segment                                               9e6564c7-7f87-44e1-8de7-7f264d9652e7
# Segment (Name/ Label)                                                            Segment 1
# ROI X Coordinate                                                            22190.41015625
# ROI Y Coordinate                                                               49197.96875
# Segment Tags                                                                     Segment 1
# AOI                                                                                      1
# AOI surface area                                                                      5034
# AOI nuclei count                                                                        39
# Fov count                                                                              555
# Fov counted                                                                            548
# BindingDensity                                                                        0.19
# Scan Name                                                             TMA_001_TNBC_240327a
# Slide                                                 28915c3d-c3ae-4cad-a109-774962c18b57
# Scan plexset                                                                             2
# Origin Instrument ID                                                             2001G0086
# #Factor                                                                                NaN
# Sample_Type                                                                        primary
# Patient                                                                      2010A18667_1L
# Scan_ID                                                               TMA_001_TNBC_240327a
# Broad_classification                                                               Primary
# ROI_ID                                                                                 003
# LOT_Human_Immune_Cell_Profiling_Protein_Core_1_1                                 ICPH10007
# LOT_Human_Immune_Activation_Status_Protein_Modu...                               IASH10003
# LOT_Human_Immune_Cell_Typing_Protein_Module_1_0                                   ICTH1006
# LOT_Human_Pan_Tumor_Protein_Module_1_0                                           PTRH10001
# LOT_Human_IO_Drug_Target_Protein_Module_1_1                                      DRGH10003
# LOT_Human_PI3K_AKT_Signaling_Protein_Module_1_0                                  PKSH10002
# LOT_Human_nC_Cell_Death_Protein_1_2                                              CLDH10001
# Well                                                                                   A03
# Row                                                                                      A
# Col                                                                                     03
# Plate                                                                                    1
#
#                                                         TMA_001_TNBC_240327a_004_Segment 1  \
# Custom Segment Name                                 TMA_001_TNBC_240327a | 004 | Segment 1
# ROI                                                   795bf454-325f-40a8-9744-3e088eb71cec
# ROI (Label)                                                                            004
# Segment                                               0c24d8bc-0bda-426f-b551-fb56e83f7c48
# Segment (Name/ Label)                                                            Segment 1
# ROI X Coordinate                                                           21641.412109375
# ROI Y Coordinate                                                               39689.90625
# Segment Tags                                                                     Segment 1
# AOI                                                                                      1
# AOI surface area                                                                     10257
# AOI nuclei count                                                                        92
# Fov count                                                                              555
# Fov counted                                                                            551
# BindingDensity                                                                         0.2
# Scan Name                                                             TMA_001_TNBC_240327a
# Slide                                                 28915c3d-c3ae-4cad-a109-774962c18b57
# Scan plexset                                                                             2
# Origin Instrument ID                                                             2001G0086
# #Factor                                                                                NaN
# Sample_Type                                                                           node
# Patient                                                                      2010A18667_2A
# Scan_ID                                                               TMA_001_TNBC_240327a
# Broad_classification                                                             Secondary
# ROI_ID                                                                                 004
# LOT_Human_Immune_Cell_Profiling_Protein_Core_1_1                                 ICPH10007
# LOT_Human_Immune_Activation_Status_Protein_Modu...                               IASH10003
# LOT_Human_Immune_Cell_Typing_Protein_Module_1_0                                   ICTH1006
# LOT_Human_Pan_Tumor_Protein_Module_1_0                                           PTRH10001
# LOT_Human_IO_Drug_Target_Protein_Module_1_1                                      DRGH10003
# LOT_Human_PI3K_AKT_Signaling_Protein_Module_1_0                                  PKSH10002
# LOT_Human_nC_Cell_Death_Protein_1_2                                              CLDH10001
# Well                                                                                   A04
# Row                                                                                      A
# Col                                                                                     04
# Plate                                                                                    1
#
#                                                         TMA_001_TNBC_240327a_005_Segment 1  \
# Custom Segment Name                                 TMA_001_TNBC_240327a | 005 | Segment 1
# ROI                                                   f95ab5f3-aa46-458d-b657-fcf4da694848
# ROI (Label)                                                                            005
# Segment                                               bb3efaed-92cb-44c8-bded-6c412faa3f28
# Segment (Name/ Label)                                                            Segment 1
# ROI X Coordinate                                                           28156.294921875
# ROI Y Coordinate                                                             46551.5703125
# Segment Tags                                                                     Segment 1
# AOI                                                                                      1
# AOI surface area                                                                     13383
# AOI nuclei count                                                                       174
# Fov count                                                                              555
# Fov counted                                                                            546
# BindingDensity                                                                         0.2
# Scan Name                                                             TMA_001_TNBC_240327a
# Slide                                                 28915c3d-c3ae-4cad-a109-774962c18b57
# Scan plexset                                                                             2
# Origin Instrument ID                                                             2001G0086
# #Factor                                                                                NaN
# Sample_Type                                                                        primary
# Patient                                                                      2012A14659_1C
# Scan_ID                                                               TMA_001_TNBC_240327a
# Broad_classification                                                               Primary
# ROI_ID                                                                                 005
# LOT_Human_Immune_Cell_Profiling_Protein_Core_1_1                                 ICPH10007
# LOT_Human_Immune_Activation_Status_Protein_Modu...                               IASH10003
# LOT_Human_Immune_Cell_Typing_Protein_Module_1_0                                   ICTH1006
# LOT_Human_Pan_Tumor_Protein_Module_1_0                                           PTRH10001
# LOT_Human_IO_Drug_Target_Protein_Module_1_1                                      DRGH10003
# LOT_Human_PI3K_AKT_Signaling_Protein_Module_1_0                                  PKSH10002
# LOT_Human_nC_Cell_Death_Protein_1_2                                              CLDH10001
# Well                                                                                   A05
# Row                                                                                      A
# Col                                                                                     05
# Plate                                                                                    1
#
#                                                         TMA_001_TNBC_240327a_006_Segment 1  \
# Custom Segment Name                                 TMA_001_TNBC_240327a | 006 | Segment 1
# ROI                                                   c2b9cab2-4124-4e13-9f5e-c634210d5af5
# ROI (Label)                                                                            006
# Segment                                               aff1a8fa-0906-450a-8e6e-190b5c311c15
# Segment (Name/ Label)                                                            Segment 1
# ROI X Coordinate                                                             29460.4453125
# ROI Y Coordinate                                                             38989.8515625
# Segment Tags                                                                     Segment 1
# AOI                                                                                      1
# AOI surface area                                                                      5161
# AOI nuclei count                                                                        78
# Fov count                                                                              555
# Fov counted                                                                            543
# BindingDensity                                                                         0.2
# Scan Name                                                             TMA_001_TNBC_240327a
# Slide                                                 28915c3d-c3ae-4cad-a109-774962c18b57
# Scan plexset                                                                             2
# Origin Instrument ID                                                             2001G0086
# #Factor                                                                                NaN
# Sample_Type                                                                           node
# Patient                                                                      2012A14659_2A
# Scan_ID                                                               TMA_001_TNBC_240327a
# Broad_classification                                                             Secondary
# ROI_ID                                                                                 006
# LOT_Human_Immune_Cell_Profiling_Protein_Core_1_1                                 ICPH10007
# LOT_Human_Immune_Activation_Status_Protein_Modu...                               IASH10003
# LOT_Human_Immune_Cell_Typing_Protein_Module_1_0                                   ICTH1006
# LOT_Human_Pan_Tumor_Protein_Module_1_0                                           PTRH10001
# LOT_Human_IO_Drug_Target_Protein_Module_1_1                                      DRGH10003
# LOT_Human_PI3K_AKT_Signaling_Protein_Module_1_0                                  PKSH10002
# LOT_Human_nC_Cell_Death_Protein_1_2                                              CLDH10001
# Well                                                                                   A06
# Row                                                                                      A
# Col                                                                                     06
# Plate                                                                                    1
#
#                                                         TMA_001_TNBC_240327a_007_Segment 1  \
# Custom Segment Name                                 TMA_001_TNBC_240327a | 007 | Segment 1
# ROI                                                   d249163c-c8a6-46ba-bbb3-a39f0f0a93d1
# ROI (Label)                                                                            007
# Segment                                               8897d9f1-29c0-4c8e-a85a-4d2317b9ee98
# Segment (Name/ Label)                                                            Segment 1
# ROI X Coordinate                                                            34450.37890625
# ROI Y Coordinate                                                            47247.91015625
# Segment Tags                                                                     Segment 1
# AOI                                                                                      1
# AOI surface area                                                                     19799
# AOI nuclei count                                                                       111
# Fov count                                                                              555
# Fov counted                                                                            548
# BindingDensity                                                                        0.18
# Scan Name                                                             TMA_001_TNBC_240327a
# Slide                                                 28915c3d-c3ae-4cad-a109-774962c18b57
# Scan plexset                                                                             2
# Origin Instrument ID                                                             2001G0086
# #Factor                                                                                NaN
# Sample_Type                                                                        primary
# Patient                                                                       2014A2999_1D
# Scan_ID                                                               TMA_001_TNBC_240327a
# Broad_classification                                                               Primary
# ROI_ID                                                                                 007
# LOT_Human_Immune_Cell_Profiling_Protein_Core_1_1                                 ICPH10007
# LOT_Human_Immune_Activation_Status_Protein_Modu...                               IASH10003
# LOT_Human_Immune_Cell_Typing_Protein_Module_1_0                                   ICTH1006
# LOT_Human_Pan_Tumor_Protein_Module_1_0                                           PTRH10001
# LOT_Human_IO_Drug_Target_Protein_Module_1_1                                      DRGH10003
# LOT_Human_PI3K_AKT_Signaling_Protein_Module_1_0                                  PKSH10002
# LOT_Human_nC_Cell_Death_Protein_1_2                                              CLDH10001
# Well                                                                                   A07
# Row                                                                                      A
# Col                                                                                     07
# Plate                                                                                    1
#
#                                                         TMA_001_TNBC_240327a_008_Segment 1  \
# Custom Segment Name                                 TMA_001_TNBC_240327a | 008 | Segment 1
# ROI                                                   77faae21-78b9-437c-8ce0-a93b8e340569
# ROI (Label)                                                                            008
# Segment                                               cfa789e4-02ec-4a0a-b079-809521dacd98
# Segment (Name/ Label)                                                            Segment 1
# ROI X Coordinate                                                             35965.6796875
# ROI Y Coordinate                                                             37720.6171875
# Segment Tags                                                                     Segment 1
# AOI                                                                                      1
# AOI surface area                                                                     14099
# AOI nuclei count                                                                       141
# Fov count                                                                              555
# Fov counted                                                                            544
# BindingDensity                                                                        0.18
# Scan Name                                                             TMA_001_TNBC_240327a
# Slide                                                 28915c3d-c3ae-4cad-a109-774962c18b57
# Scan plexset                                                                             2
# Origin Instrument ID                                                             2001G0086
# #Factor                                                                                NaN
# Sample_Type                                                                           node
# Patient                                                                       2014A2999_2A
# Scan_ID                                                               TMA_001_TNBC_240327a
# Broad_classification                                                             Secondary
# ROI_ID                                                                                 008
# LOT_Human_Immune_Cell_Profiling_Protein_Core_1_1                                 ICPH10007
# LOT_Human_Immune_Activation_Status_Protein_Modu...                               IASH10003
# LOT_Human_Immune_Cell_Typing_Protein_Module_1_0                                   ICTH1006
# LOT_Human_Pan_Tumor_Protein_Module_1_0                                           PTRH10001
# LOT_Human_IO_Drug_Target_Protein_Module_1_1                                      DRGH10003
# LOT_Human_PI3K_AKT_Signaling_Protein_Module_1_0                                  PKSH10002
# LOT_Human_nC_Cell_Death_Protein_1_2                                              CLDH10001
# Well                                                                                   A08
# Row                                                                                      A
# Col                                                                                     08
# Plate                                                                                    1
#
#                                                         TMA_001_TNBC_240327a_009_Segment 1  \
# Custom Segment Name                                 TMA_001_TNBC_240327a | 009 | Segment 1
# ROI                                                   a33ff91d-2a1c-47c5-be42-c03423987723
# ROI (Label)                                                                            009
# Segment                                               2e38b3b5-6108-4c67-bae4-1407b409ed5d
# Segment (Name/ Label)                                                            Segment 1
# ROI X Coordinate                                                          14040.1318359375
# ROI Y Coordinate                                                             33845.1171875
# Segment Tags                                                                     Segment 1
# AOI                                                                                      1
# AOI surface area                                                                      9946
# AOI nuclei count                                                                       124
# Fov count                                                                              555
# Fov counted                                                                            546
# BindingDensity                                                                        0.18
# Scan Name                                                             TMA_001_TNBC_240327a
# Slide                                                 28915c3d-c3ae-4cad-a109-774962c18b57
# Scan plexset                                                                             2
# Origin Instrument ID                                                             2001G0086
# #Factor                                                                                NaN
# Sample_Type                                                                        primary
# Patient                                                                       2012A6999_1C
# Scan_ID                                                               TMA_001_TNBC_240327a
# Broad_classification                                                               Primary
# ROI_ID                                                                                 009
# LOT_Human_Immune_Cell_Profiling_Protein_Core_1_1                                 ICPH10007
# LOT_Human_Immune_Activation_Status_Protein_Modu...                               IASH10003
# LOT_Human_Immune_Cell_Typing_Protein_Module_1_0                                   ICTH1006
# LOT_Human_Pan_Tumor_Protein_Module_1_0                                           PTRH10001
# LOT_Human_IO_Drug_Target_Protein_Module_1_1                                      DRGH10003
# LOT_Human_PI3K_AKT_Signaling_Protein_Module_1_0                                  PKSH10002
# LOT_Human_nC_Cell_Death_Protein_1_2                                              CLDH10001
# Well                                                                                   A09
# Row                                                                                      A
# Col                                                                                     09
# Plate                                                                                    1
#
#                                                         TMA_001_TNBC_240327a_010_Segment 1  \
# Custom Segment Name                                 TMA_001_TNBC_240327a | 010 | Segment 1
# ROI                                                   853d0bb8-b16b-4567-8a75-c1127af5e57f
# ROI (Label)                                                                            010
# Segment                                               b428322e-fb26-4468-bc22-6880eb3d74d6
# Segment (Name/ Label)                                                            Segment 1
# ROI X Coordinate                                                              22770.828125
# ROI Y Coordinate                                                            32324.01171875
# Segment Tags                                                                     Segment 1
# AOI                                                                                      1
# AOI surface area                                                                      4358
# AOI nuclei count                                                                        44
# Fov count                                                                              555
# Fov counted                                                                            549
# BindingDensity                                                                        0.18
# Scan Name                                                             TMA_001_TNBC_240327a
# Slide                                                 28915c3d-c3ae-4cad-a109-774962c18b57
# Scan plexset                                                                             2
# Origin Instrument ID                                                             2001G0086
# #Factor                                                                                NaN
# Sample_Type                                                                        primary
# Patient                                                                      2011A12015_2A
# Scan_ID                                                               TMA_001_TNBC_240327a
# Broad_classification                                                               Primary
# ROI_ID                                                                                 010
# LOT_Human_Immune_Cell_Profiling_Protein_Core_1_1                                 ICPH10007
# LOT_Human_Immune_Activation_Status_Protein_Modu...                               IASH10003
# LOT_Human_Immune_Cell_Typing_Protein_Module_1_0                                   ICTH1006
# LOT_Human_Pan_Tumor_Protein_Module_1_0                                           PTRH10001
# LOT_Human_IO_Drug_Target_Protein_Module_1_1                                      DRGH10003
# LOT_Human_PI3K_AKT_Signaling_Protein_Module_1_0                                  PKSH10002
# LOT_Human_nC_Cell_Death_Protein_1_2                                              CLDH10001
# Well                                                                                   A10
# Row                                                                                      A
# Col                                                                                     10
# Plate                                                                                    1
#
#                                                     ...  \
# Custom Segment Name                                 ...
# ROI                                                 ...
# ROI (Label)                                         ...
# Segment                                             ...
# Segment (Name/ Label)                               ...
# ROI X Coordinate                                    ...
# ROI Y Coordinate                                    ...
# Segment Tags                                        ...
# AOI                                                 ...
# AOI surface area                                    ...
# AOI nuclei count                                    ...
# Fov count                                           ...
# Fov counted                                         ...
# BindingDensity                                      ...
# Scan Name                                           ...
# Slide                                               ...
# Scan plexset                                        ...
# Origin Instrument ID                                ...
# #Factor                                             ...
# Sample_Type                                         ...
# Patient                                             ...
# Scan_ID                                             ...
# Broad_classification                                ...
# ROI_ID                                              ...
# LOT_Human_Immune_Cell_Profiling_Protein_Core_1_1    ...
# LOT_Human_Immune_Activation_Status_Protein_Modu...  ...
# LOT_Human_Immune_Cell_Typing_Protein_Module_1_0     ...
# LOT_Human_Pan_Tumor_Protein_Module_1_0              ...
# LOT_Human_IO_Drug_Target_Protein_Module_1_1         ...
# LOT_Human_PI3K_AKT_Signaling_Protein_Module_1_0     ...
# LOT_Human_nC_Cell_Death_Protein_1_2                 ...
# Well                                                ...
# Row                                                 ...
# Col                                                 ...
# Plate                                               ...
#
#                                                         TMA_002_TNBC_240327_029_Segment 1  \
# Custom Segment Name                                 TMA_002_TNBC_240327 | 029 | Segment 1
# ROI                                                  852af546-4f91-4845-a36c-c49449eb1ee6
# ROI (Label)                                                                           029
# Segment                                              47ef0fac-b270-450b-a899-19afaf3a8c49
# Segment (Name/ Label)                                                           Segment 1
# ROI X Coordinate                                                         16045.6611328125
# ROI Y Coordinate                                                           42486.55859375
# Segment Tags                                                                    Segment 1
# AOI                                                                                     1
# AOI surface area                                                                    20045
# AOI nuclei count                                                                      111
# Fov count                                                                             555
# Fov counted                                                                           548
# BindingDensity                                                                       0.19
# Scan Name                                                             TMA_002_TNBC_240327
# Slide                                                8ff60af2-0133-4d57-8720-9d46237069bf
# Scan plexset                                                                            2
# Origin Instrument ID                                                            2001G0086
# #Factor                                                                               NaN
# Sample_Type                                                                       primary
# Patient                                                                     2014A18014_1I
# Scan_ID                                                               TMA_002_TNBC_240327
# Broad_classification                                                              Primary
# ROI_ID                                                                                029
# LOT_Human_Immune_Cell_Profiling_Protein_Core_1_1                                ICPH10007
# LOT_Human_Immune_Activation_Status_Protein_Modu...                              IASH10003
# LOT_Human_Immune_Cell_Typing_Protein_Module_1_0                                 ICTH10006
# LOT_Human_Pan_Tumor_Protein_Module_1_0                                          PTRH10001
# LOT_Human_IO_Drug_Target_Protein_Module_1_1                                     DRGH10003
# LOT_Human_PI3K_AKT_Signaling_Protein_Module_1_0                                 PKSH10002
# LOT_Human_nC_Cell_Death_Protein_1_2                                             CLDH10001
# Well                                                                                  H03
# Row                                                                                     H
# Col                                                                                    03
# Plate                                                                                   1
#
#                                                         TMA_002_TNBC_240327_030_Segment 1  \
# Custom Segment Name                                 TMA_002_TNBC_240327 | 030 | Segment 1
# ROI                                                  3d1960fd-9a3d-4635-89cb-d6093cbf81de
# ROI (Label)                                                                           030
# Segment                                              5fd178e2-2b3d-40b0-b9fb-b1158c7d3113
# Segment (Name/ Label)                                                           Segment 1
# ROI X Coordinate                                                          18286.287109375
# ROI Y Coordinate                                                           44687.47265625
# Segment Tags                                                                    Segment 1
# AOI                                                                                     1
# AOI surface area                                                                    18220
# AOI nuclei count                                                                      176
# Fov count                                                                             555
# Fov counted                                                                           551
# BindingDensity                                                                        0.2
# Scan Name                                                             TMA_002_TNBC_240327
# Slide                                                8ff60af2-0133-4d57-8720-9d46237069bf
# Scan plexset                                                                            2
# Origin Instrument ID                                                            2001G0086
# #Factor                                                                               NaN
# Sample_Type                                                                       primary
# Patient                                                                     2014A18014_1I
# Scan_ID                                                               TMA_002_TNBC_240327
# Broad_classification                                                              Primary
# ROI_ID                                                                                030
# LOT_Human_Immune_Cell_Profiling_Protein_Core_1_1                                ICPH10007
# LOT_Human_Immune_Activation_Status_Protein_Modu...                              IASH10003
# LOT_Human_Immune_Cell_Typing_Protein_Module_1_0                                 ICTH10006
# LOT_Human_Pan_Tumor_Protein_Module_1_0                                          PTRH10001
# LOT_Human_IO_Drug_Target_Protein_Module_1_1                                     DRGH10003
# LOT_Human_PI3K_AKT_Signaling_Protein_Module_1_0                                 PKSH10002
# LOT_Human_nC_Cell_Death_Protein_1_2                                             CLDH10001
# Well                                                                                  H04
# Row                                                                                     H
# Col                                                                                    04
# Plate                                                                                   1
#
#                                                         TMA_002_TNBC_240327_031_Segment 1  \
# Custom Segment Name                                 TMA_002_TNBC_240327 | 031 | Segment 1
# ROI                                                  2577a945-3961-427a-912d-10dc93135cac
# ROI (Label)                                                                           031
# Segment                                              8ece77c9-a4cc-4926-9f90-f9d892cb6a51
# Segment (Name/ Label)                                                           Segment 1
# ROI X Coordinate                                                         15990.0439453125
# ROI Y Coordinate                                                              53921.28125
# Segment Tags                                                                    Segment 1
# AOI                                                                                     1
# AOI surface area                                                                    18991
# AOI nuclei count                                                                       94
# Fov count                                                                             555
# Fov counted                                                                           546
# BindingDensity                                                                        0.2
# Scan Name                                                             TMA_002_TNBC_240327
# Slide                                                8ff60af2-0133-4d57-8720-9d46237069bf
# Scan plexset                                                                            2
# Origin Instrument ID                                                            2001G0086
# #Factor                                                                               NaN
# Sample_Type                                                                       primary
# Patient                                                                     2014A20860_1F
# Scan_ID                                                               TMA_002_TNBC_240327
# Broad_classification                                                              Primary
# ROI_ID                                                                                031
# LOT_Human_Immune_Cell_Profiling_Protein_Core_1_1                                ICPH10007
# LOT_Human_Immune_Activation_Status_Protein_Modu...                              IASH10003
# LOT_Human_Immune_Cell_Typing_Protein_Module_1_0                                 ICTH10006
# LOT_Human_Pan_Tumor_Protein_Module_1_0                                          PTRH10001
# LOT_Human_IO_Drug_Target_Protein_Module_1_1                                     DRGH10003
# LOT_Human_PI3K_AKT_Signaling_Protein_Module_1_0                                 PKSH10002
# LOT_Human_nC_Cell_Death_Protein_1_2                                             CLDH10001
# Well                                                                                  H05
# Row                                                                                     H
# Col                                                                                    05
# Plate                                                                                   1
#
#                                                         TMA_002_TNBC_240327_032_Segment 1  \
# Custom Segment Name                                 TMA_002_TNBC_240327 | 032 | Segment 1
# ROI                                                  18c6bdc1-6bc1-4053-9afb-3a10cb0dc60d
# ROI (Label)                                                                           032
# Segment                                              528d80c9-6779-47c6-94ef-64c720aba698
# Segment (Name/ Label)                                                           Segment 1
# ROI X Coordinate                                                            9614.58203125
# ROI Y Coordinate                                                             46081.296875
# Segment Tags                                                                    Segment 1
# AOI                                                                                     1
# AOI surface area                                                                    13875
# AOI nuclei count                                                                      164
# Fov count                                                                             555
# Fov counted                                                                           543
# BindingDensity                                                                        0.2
# Scan Name                                                             TMA_002_TNBC_240327
# Slide                                                8ff60af2-0133-4d57-8720-9d46237069bf
# Scan plexset                                                                            2
# Origin Instrument ID                                                            2001G0086
# #Factor                                                                               NaN
# Sample_Type                                                                       primary
# ...
# Segment Tags                                                                    Segment 1
# AOI                                                                                     1
# AOI surface area                                                                     8883
# AOI nuclei count                                                                       91
# Fov count                                                                             555
# Fov counted                                                                           544
# BindingDensity                                                                       0.18
# Scan Name                                                             TMA_002_TNBC_240327
# Slide                                                8ff60af2-0133-4d57-8720-9d46237069bf
# Scan plexset                                                                            2
# Origin Instrument ID                                                            2001G0086
# #Factor                                                                               NaN
# Sample_Type                                                                       primary
# Patient                                                                         2014A6197
# Scan_ID                                                               TMA_002_TNBC_240327
# Broad_classification                                                              Primary
# ROI_ID                                                                                034
# LOT_Human_Immune_Cell_Profiling_Protein_Core_1_1                                ICPH10007
# LOT_Human_Immune_Activation_Status_Protein_Modu...                              IASH10003
# LOT_Human_Immune_Cell_Typing_Protein_Module_1_0                                 ICTH10006
# LOT_Human_Pan_Tumor_Protein_Module_1_0                                          PTRH10001
# LOT_Human_IO_Drug_Target_Protein_Module_1_1                                     DRGH10003
# LOT_Human_PI3K_AKT_Signaling_Protein_Module_1_0                                 PKSH10002
# LOT_Human_nC_Cell_Death_Protein_1_2                                             CLDH10001
# Well                                                                                  H08
# Row                                                                                     H
# Col                                                                                    08
# Plate                                                                                   1
#
#                                                         TMA_002_TNBC_240327_035_Segment 1  \
# Custom Segment Name                                 TMA_002_TNBC_240327 | 035 | Segment 1
# ROI                                                  575d0d4c-a539-4ea9-a9c5-fa3df2aadfd8
# ROI (Label)                                                                           035
# Segment                                              fa9c6ff6-c60a-4d6e-8065-9521674aeb0e
# Segment (Name/ Label)                                                           Segment 1
# ROI X Coordinate                                                                    17818
# ROI Y Coordinate                                                                    22113
# Segment Tags                                                                    Segment 1
# AOI                                                                                     1
# AOI surface area                                                                    10835
# AOI nuclei count                                                                      103
# Fov count                                                                             555
# Fov counted                                                                           546
# BindingDensity                                                                       0.18
# Scan Name                                                             TMA_002_TNBC_240327
# Slide                                                8ff60af2-0133-4d57-8720-9d46237069bf
# Scan plexset                                                                            2
# Origin Instrument ID                                                            2001G0086
# #Factor                                                                               NaN
# Sample_Type                                                                       primary
# Patient                                                                         2014A6197
# Scan_ID                                                               TMA_002_TNBC_240327
# Broad_classification                                                              Primary
# ROI_ID                                                                                035
# LOT_Human_Immune_Cell_Profiling_Protein_Core_1_1                                ICPH10007
# LOT_Human_Immune_Activation_Status_Protein_Modu...                              IASH10003
# LOT_Human_Immune_Cell_Typing_Protein_Module_1_0                                 ICTH10006
# LOT_Human_Pan_Tumor_Protein_Module_1_0                                          PTRH10001
# LOT_Human_IO_Drug_Target_Protein_Module_1_1                                     DRGH10003
# LOT_Human_PI3K_AKT_Signaling_Protein_Module_1_0                                 PKSH10002
# LOT_Human_nC_Cell_Death_Protein_1_2                                             CLDH10001
# Well                                                                                  H09
# Row                                                                                     H
# Col                                                                                    09
# Plate                                                                                   1
#
#                                                         TMA_002_TNBC_240327_036_Segment 1  \
# Custom Segment Name                                 TMA_002_TNBC_240327 | 036 | Segment 1
# ROI                                                  17d4cd04-13ca-4edc-bdf5-85be0cbd264b
# ROI (Label)                                                                           036
# Segment                                              98b86df7-0282-422b-8758-24a7bdeec98d
# Segment (Name/ Label)                                                           Segment 1
# ROI X Coordinate                                                                    10855
# ROI Y Coordinate                                                                    29783
# Segment Tags                                                                    Segment 1
# AOI                                                                                     1
# AOI surface area                                                                     5073
# AOI nuclei count                                                                       42
# Fov count                                                                             555
# Fov counted                                                                           549
# BindingDensity                                                                       0.18
# Scan Name                                                             TMA_002_TNBC_240327
# Slide                                                8ff60af2-0133-4d57-8720-9d46237069bf
# Scan plexset                                                                            2
# Origin Instrument ID                                                            2001G0086
# #Factor                                                                               NaN
# Sample_Type                                                                       primary
# Patient                                                                     2015A12897_1J
# Scan_ID                                                               TMA_002_TNBC_240327
# Broad_classification                                                              Primary
# ROI_ID                                                                                036
# LOT_Human_Immune_Cell_Profiling_Protein_Core_1_1                                ICPH10007
# LOT_Human_Immune_Activation_Status_Protein_Modu...                              IASH10003
# LOT_Human_Immune_Cell_Typing_Protein_Module_1_0                                 ICTH10006
# LOT_Human_Pan_Tumor_Protein_Module_1_0                                          PTRH10001
# LOT_Human_IO_Drug_Target_Protein_Module_1_1                                     DRGH10003
# LOT_Human_PI3K_AKT_Signaling_Protein_Module_1_0                                 PKSH10002
# LOT_Human_nC_Cell_Death_Protein_1_2                                             CLDH10001
# Well                                                                                  H10
# Row                                                                                     H
# Col                                                                                    10
# Plate                                                                                   1
#
#                                                         TMA_002_TNBC_240327_037_Segment 1  \
# Custom Segment Name                                 TMA_002_TNBC_240327 | 037 | Segment 1
# ROI                                                  da0594eb-7ac1-454e-8fe1-18754987426f
# ROI (Label)                                                                           037
# Segment                                              990b2e46-dd95-435f-8a53-72cc2096df4d
# Segment (Name/ Label)                                                           Segment 1
# ROI X Coordinate                                                                    18335
# ROI Y Coordinate                                                                    38071
# Segment Tags                                                                    Segment 1
# AOI                                                                                     1
# AOI surface area                                                                     5366
# AOI nuclei count                                                                       87
# Fov count                                                                             555
# Fov counted                                                                           549
# BindingDensity                                                                        0.2
# Scan Name                                                             TMA_002_TNBC_240327
# Slide                                                8ff60af2-0133-4d57-8720-9d46237069bf
# Scan plexset                                                                            2
# Origin Instrument ID                                                            2001G0086
# #Factor                                                                               NaN
# Sample_Type                                                                       primary
# Patient                                                                     2014A17604_1F
# Scan_ID                                                               TMA_002_TNBC_240327
# Broad_classification                                                              Primary
# ROI_ID                                                                                037
# LOT_Human_Immune_Cell_Profiling_Protein_Core_1_1                                ICPH10007
# LOT_Human_Immune_Activation_Status_Protein_Modu...                              IASH10003
# LOT_Human_Immune_Cell_Typing_Protein_Module_1_0                                 ICTH10006
# LOT_Human_Pan_Tumor_Protein_Module_1_0                                          PTRH10001
# LOT_Human_IO_Drug_Target_Protein_Module_1_1                                     DRGH10003
# LOT_Human_PI3K_AKT_Signaling_Protein_Module_1_0                                 PKSH10002
# LOT_Human_nC_Cell_Death_Protein_1_2                                             CLDH10001
# Well                                                                                  H11
# Row                                                                                     H
# Col                                                                                    11
# Plate                                                                                   1
#
#                                                         TMA_002_TNBC_240327_038_Segment 1
# Custom Segment Name                                 TMA_002_TNBC_240327 | 038 | Segment 1
# ROI                                                  7e12d16f-bb81-4172-aa51-7da692483286
# ROI (Label)                                                                           038
# Segment                                              54be0368-acf2-4d5c-809c-6a878f988fca
# Segment (Name/ Label)                                                           Segment 1
# ROI X Coordinate                                                                    10963
# ROI Y Coordinate                                                                    43305
# Segment Tags                                                                    Segment 1
# AOI                                                                                     1
# AOI surface area                                                                     5531
# AOI nuclei count                                                                       72
# Fov count                                                                             555
# Fov counted                                                                           546
# BindingDensity                                                                       0.17
# Scan Name                                                             TMA_002_TNBC_240327
# Slide                                                8ff60af2-0133-4d57-8720-9d46237069bf
# Scan plexset                                                                            2
# Origin Instrument ID                                                            2001G0086
# #Factor                                                                               NaN
# Sample_Type                                                                       primary
# Patient                                                                      2015A9148_1G
# Scan_ID                                                               TMA_002_TNBC_240327
# Broad_classification                                                              Primary
# ROI_ID                                                                                038
# LOT_Human_Immune_Cell_Profiling_Protein_Core_1_1                                ICPH10007
# LOT_Human_Immune_Activation_Status_Protein_Modu...                              IASH10003
# LOT_Human_Immune_Cell_Typing_Protein_Module_1_0                                 ICTH10006
# LOT_Human_Pan_Tumor_Protein_Module_1_0                                          PTRH10001
# LOT_Human_IO_Drug_Target_Protein_Module_1_1                                     DRGH10003
# LOT_Human_PI3K_AKT_Signaling_Protein_Module_1_0                                 PKSH10002
# LOT_Human_nC_Cell_Death_Protein_1_2                                             CLDH10001
# Well                                                                                  H12
# Row                                                                                     H
# Col                                                                                    12
# Plate                                                                                   1
#
# [35 rows x 96 columns]

# %%
colTemp = sampleInfo.columns
colTemp = [x.replace(' ','.') for x in colTemp]
colTemp = [x.replace('-','.') for x in colTemp]
sampleInfo.columns = colTemp

# %%
factors = input('enter factors to be used for groups to check probe expression. separate multiple factors by a comma')
# Out:
# enter factors to be used for groups to check probe expression. separate multiple factors by a comma

# %%
factors = factors.split(',')
factors = [f.strip() for f in factors]

# %%
# factors = ['Sample_Type', 'Patient', 'Broad_classification']
factors = ['Broad_classification']
factors
# Out:
# ['Broad_classification']

# %%
# generate a dictionary to hold factors for group analysis
factorDict = {}
factorDict2 = {}

for f in factors:
    entries = list(set(sampleInfo.loc[f].values))
    print(entries)
    factorDict[f] = entries
    factorDict2[f] = {}
    for e in entries:
        factorDict2[f][e] = sampleInfo.columns[sampleInfo.loc[f] == e]
# Out:
# ['Primary', 'Secondary']

# %%
factorDict.keys()
# Out:
# dict_keys(['Broad_classification'])

# %%
factorDict2
# Out:
# {'Broad_classification': {'Primary': Index(['TMA_001_TNBC_240327a_001_Segment.1',
#          'TMA_001_TNBC_240327a_003_Segment.1',
#          'TMA_001_TNBC_240327a_005_Segment.1',
#          'TMA_001_TNBC_240327a_007_Segment.1',
#          'TMA_001_TNBC_240327a_009_Segment.1',
#          'TMA_001_TNBC_240327a_010_Segment.1',
#          'TMA_001_TNBC_240327a_011_Segment.1',
#          'TMA_001_TNBC_240327a_015_Segment.1',
#          'TMA_001_TNBC_240327a_016_Segment.1',
#          'TMA_001_TNBC_240327a_017_Segment.1',
#          'TMA_001_TNBC_240327a_020_Segment.1',
#          'TMA_001_TNBC_240327a_021_Segment.1',
#          'TMA_001_TNBC_240327a_023_Segment.1',
#          'TMA_001_TNBC_240327a_024_Segment.1',
#          'TMA_001_TNBC_240327a_026_Segment.1',
#          'TMA_001_TNBC_240327a_028_Segment.1',
#          'TMA_001_TNBC_240327a_031_Segment.1',
#          'TMA_001_TNBC_240327a_034_Segment.1',
#          'TMA_001_TNBC_240327a_037_Segment.1',
#          'TMA_001_TNBC_240327a_040_Segment.1',
#          'TMA_001_TNBC_240327a_041_Segment.1',
#          'TMA_001_TNBC_240327a_042_Segment.1',
#          'TMA_001_TNBC_240327a_043_Segment.1',
#          'TMA_001_TNBC_240327a_048_Segment.1',
#          'TMA_001_TNBC_240327a_050_Segment.1',
#          'TMA_001_TNBC_240327a_051_Segment.1',
#          'TMA_001_TNBC_240327a_052_Segment.1',
#          'TMA_001_TNBC_240327a_056_Segment.1',
#          'TMA_001_TNBC_240327a_057_Segment.1',
#          'TMA_001_TNBC_240327a_058_Segment.1',
#          'TMA_002_TNBC_240327_001_Segment.1',
#          'TMA_002_TNBC_240327_002_Segment.1',
#          'TMA_002_TNBC_240327_005_Segment.1',
#          'TMA_002_TNBC_240327_006_Segment.1',
#          'TMA_002_TNBC_240327_007_Segment.1',
#          'TMA_002_TNBC_240327_008_Segment.1',
#          'TMA_002_TNBC_240327_014_Segment.1',
#          'TMA_002_TNBC_240327_015_Segment.1',
#          'TMA_002_TNBC_240327_016_Segment.1',
#          'TMA_002_TNBC_240327_017_Segment.1',
#          'TMA_002_TNBC_240327_018_Segment.1',
#          'TMA_002_TNBC_240327_019_Segment.1',
#          'TMA_002_TNBC_240327_020_Segment.1',
#          'TMA_002_TNBC_240327_021_Segment.1',
#          'TMA_002_TNBC_240327_022_Segment.1',
#          'TMA_002_TNBC_240327_023_Segment.1',
#          'TMA_002_TNBC_240327_027_Segment.1',
#          'TMA_002_TNBC_240327_028_Segment.1',
#          'TMA_002_TNBC_240327_029_Segment.1',
#          'TMA_002_TNBC_240327_030_Segment.1',
#          'TMA_002_TNBC_240327_031_Segment.1',
#          'TMA_002_TNBC_240327_032_Segment.1',
#          'TMA_002_TNBC_240327_033_Segment.1',
#          'TMA_002_TNBC_240327_034_Segment.1',
#          'TMA_002_TNBC_240327_035_Segment.1',
#          'TMA_002_TNBC_240327_036_Segment.1',
#          'TMA_002_TNBC_240327_037_Segment.1',
#          'TMA_002_TNBC_240327_038_Segment.1'],
#         dtype='object'),
#   'Secondary': Index(['TMA_001_TNBC_240327a_002_Segment.1',
#          'TMA_001_TNBC_240327a_004_Segment.1',
#          'TMA_001_TNBC_240327a_006_Segment.1',
#          'TMA_001_TNBC_240327a_008_Segment.1',
#          'TMA_001_TNBC_240327a_012_Segment.1',
#          'TMA_001_TNBC_240327a_013_Segment.1',
#          'TMA_001_TNBC_240327a_014_Segment.1',
#          'TMA_001_TNBC_240327a_018_Segment.1',
#          'TMA_001_TNBC_240327a_019_Segment.1',
#          'TMA_001_TNBC_240327a_022_Segment.1',
#          'TMA_001_TNBC_240327a_025_Segment.1',
#          'TMA_001_TNBC_240327a_027_Segment.1',
#          'TMA_001_TNBC_240327a_029_Segment.1',
#          'TMA_001_TNBC_240327a_030_Segment.1',
#          'TMA_001_TNBC_240327a_032_Segment.1',
#          'TMA_001_TNBC_240327a_033_Segment.1',
#          'TMA_001_TNBC_240327a_035_Segment.1',
#          'TMA_001_TNBC_240327a_036_Segment.1',
#          'TMA_001_TNBC_240327a_038_Segment.1',
#          'TMA_001_TNBC_240327a_039_Segment.1',
#          'TMA_001_TNBC_240327a_044_Segment.1',
#          'TMA_001_TNBC_240327a_045_Segment.1',
#          'TMA_001_TNBC_240327a_046_Segment.1',
#          'TMA_001_TNBC_240327a_047_Segment.1',
#          'TMA_001_TNBC_240327a_049_Segment.1',
#          'TMA_001_TNBC_240327a_053_Segment.1',
#          'TMA_001_TNBC_240327a_054_Segment.1',
#          'TMA_001_TNBC_240327a_055_Segment.1',
#          'TMA_002_TNBC_240327_003_Segment.1',
#          'TMA_002_TNBC_240327_004_Segment.1',
#          'TMA_002_TNBC_240327_009_Segment.1',
#          'TMA_002_TNBC_240327_010_Segment.1',
#          'TMA_002_TNBC_240327_011_Segment.1',
#          'TMA_002_TNBC_240327_012_Segment.1',
#          'TMA_002_TNBC_240327_013_Segment.1',
#          'TMA_002_TNBC_240327_024_Segment.1',
#          'TMA_002_TNBC_240327_025_Segment.1',
#          'TMA_002_TNBC_240327_026_Segment.1'],
#         dtype='object')}}

# %% [markdown]
# # Visualise Nanostring Norm results and choose samples to be kept for final normalisation

# %%
configDict
# Out:
# {'rootDir': '/Users/upton6/Documents/Nanostring/projects/Adams/',
#  'initialDataPath': 'Initial Dataset.xlsx',
#  'QCDataPath': 'Default_QC.xlsx',
#  'labWorksheet01Path': 'Lab_Worksheet_P1001660017100A.txt',
#  'sampleInfoFile': 'sampleInfo_with_Wells.csv',
#  'projectName': 'Adams_Bray'}

# %%
normDir = os.path.join(configDict['rootDir'], 'Normalisation')

# %%
normDir
# Out:
# '/Users/upton6/Documents/Nanostring/projects/Adams/Normalisation'

# %%
QCDataFile = [f for f in os.listdir(normDir) if (f.startswith('QC') and f.endswith('RUV.csv'))][0]

# %%
QCDataFile
# Out:
# 'QC_Adams_Bray_RUV.csv'

# %%
# tempDF

# %% [markdown]
# ### Sort samples and probes

# %%
# tempDF1 = pd.read_csv(os.path.join(normDir, 'NSNorm',files[0]), index_col=0)
# v = tempDF1.mean(axis=1).sort_values().index

# sampleOrder = sorted(tempDF1.columns)

# %%
QCDataDF = pd.read_csv(os.path.join(normDir, QCDataFile), index_col=0)
QCDataDF.columns = [x.replace(' ','.') for x in QCDataDF.columns]
QCDataDF.columns = [x.replace('-','.') for x in QCDataDF.columns]


probeOrder = QCDataDF.index[8:]
sampleOrder = QCDataDF.columns[1:]

# sampleOrder

# %%
files = os.listdir(os.path.join(normDir, 'NSNorm'))
files = sorted(files)
# # print(len(files))
# # print(files)

# fileIdx = 0
# tempFile = os.path.join(normDir, 'NSNorm',files[fileIdx])

# print(tempFile)
# tempDF = pd.read_csv(os.path.join(normDir, 'NSNorm',files[fileIdx]), index_col=0)

# %%
probeOrder
# Out:
# Index(['CD8', 'CD4', 'GZMB', 'Fibronectin', 'Beta-2-microglobulin', 'PD-1',
#        'HLA-DR', 'CD3', 'CD56', 'CD11c', 'CTLA4', 'CD68', 'PanCk', 'SMA',
#        'CD20', 'PD-L1', 'CD45', 'Ki-67', 'CD25', 'ICOS', 'CD80', 'CD27',
#        'PD-L2', 'CD127', 'CD40', 'CD44', 'CD34', 'CD163', 'CD45RO', 'FOXP3',
#        'CD14', 'FAP-alpha', 'CD66b', 'PTEN', 'EpCAM', 'Her2', 'S100B', 'Bcl-2',
#        'NY-ESO-1', 'PR', 'MART1', 'ER-alpha', 'IDO1', 'Tim-3', '4-1BB',
#        'STING', 'GITR', 'OX40L', 'VISTA', 'B7-H3', 'LAG3', 'ARG1', 'MET',
#        'INPP4B', 'PLCG1', 'Phospho-GSK3A (S21)/Phospho-GSK3B (S9)',
#        'Phospho-Tuberin (T1462)', 'Phospho-AKT1 (S473)', 'Pan-AKT',
#        'Phospho-PRAS40 (T246)', 'Phospho-GSK3B (S9)', 'BCLXL', 'BIM', 'BCL6',
#        'CD95/Fas', 'BAD', 'PARP', 'p53', 'Neurofibromin', 'GZMA',
#        'Cleaved Caspase 9'],
#       dtype='object', name='Name')

# %%
width = 6
height = 14


fig, axs = plt.subplots(height, width, figsize=[40,25])
# fig.suptitle('Nanostring Normalisation heatmaps')

for y in range(height):
    for x in range(width):
        fileIdx = x + y*width
        tempDF = pd.read_csv(os.path.join(normDir, 'NSNorm',files[fileIdx]), index_col=0)
#         axs[y][x].matshow(np.log2(tempDF + 1), aspect = 'auto', cmap='coolwarm')
        axs[y][x].matshow(np.log2(tempDF.loc[probeOrder,sampleOrder] + 1), cmap='coolwarm')
        axs[y][x].set_xticks([])
        axs[y][x].set_yticks([])
        axs[y][x].set_title(files[fileIdx][:-4])
    
# plt.tight_layout()
# fig.show()
fig.savefig('NSNorm.png')

# %% [markdown]
# # Threshold data

# %%
controlSet = set(['HYB-NEG', 'HYB-POS', 'Rb IgG', 'Ms IgG2a', 'Ms IgG1'])

# %% [markdown]
# ### Threshold probes and drop low or null expressing probes

# %%
threshold = 1.5
expPropCutOff = 0.5
SamplePropCutOff = 0.5

dropList = []

dropSetTemp = []

for f in factorDict2.keys():
    print(f)
    for g in factorDict2[f].keys():
        print(g)
        # print(factorDict2[f][g])
        groupLen = len(factorDict2[f][g])
        # print(groupLen)
        passThreshold = (QCDataDF[factorDict2[f][g]]>threshold).sum(axis=1)
        # print(passThreshold)
        passThreshProp = (passThreshold/groupLen) < expPropCutOff
        # print(passThreshProp)
        failIdx = QCDataDF.index[passThreshProp]
        print(failIdx)
        print(len(failIdx))

        if (len(failIdx) > 0):
            dropList.extend(list(failIdx))
            dropSetTemp.append(list(failIdx))
        # print(QCDataDF.index[((QCDataDF[factorDict2[f][g]]>2).sum(axis=1)/groupLen) < 0.5])

dropList = list(set(dropList) - controlSet)
print(dropList)
print(dropSetTemp)

# dropSet = set(tuple(x) for x in dropSetTemp)
# Out:
# Broad_classification
# Primary
# Index(['HYB-NEG', 'CD80', 'CD27', 'PD-L2', 'CD40', 'CD163', 'FOXP3', 'CD66b',
#        'PR', 'MART1', 'GITR', 'B7-H3', 'LAG3', 'ARG1', 'PLCG1',
#        'Phospho-Tuberin (T1462)', 'Phospho-GSK3B (S9)'],
#       dtype='object', name='Name')
# 17
# Secondary
# Index(['HYB-NEG', 'CD80', 'CD27', 'PD-L2', 'CD34', 'CD163', 'PR', 'MART1',
#        'B7-H3', 'LAG3', 'ARG1', 'PLCG1', 'Phospho-Tuberin (T1462)',
#        'Phospho-GSK3B (S9)'],
#       dtype='object', name='Name')
# 14
# ['B7-H3', 'LAG3', 'CD80', 'CD34', 'CD27', 'FOXP3', 'ARG1', 'PR', 'PD-L2', 'CD40', 'CD163', 'CD66b', 'Phospho-GSK3B (S9)', 'MART1', 'PLCG1', 'Phospho-Tuberin (T1462)', 'GITR']
# [['HYB-NEG', 'CD80', 'CD27', 'PD-L2', 'CD40', 'CD163', 'FOXP3', 'CD66b', 'PR', 'MART1', 'GITR', 'B7-H3', 'LAG3', 'ARG1', 'PLCG1', 'Phospho-Tuberin (T1462)', 'Phospho-GSK3B (S9)'], ['HYB-NEG', 'CD80', 'CD27', 'PD-L2', 'CD34', 'CD163', 'PR', 'MART1', 'B7-H3', 'LAG3', 'ARG1', 'PLCG1', 'Phospho-Tuberin (T1462)', 'Phospho-GSK3B (S9)']]

# %%
dropSet = set(dropSetTemp[0])

for x in range(1,len(dropSetTemp)):
    print(x)
    dropSet = dropSet & set(dropSetTemp[1])

dropSet = dropSet - controlSet
# dropSet
dropList = list(dropSet)
# dropList
QCDataDF = QCDataDF.drop(index=dropList)
# Out:
# 1

# %% [markdown]
# ### Threshold samples and drop low or null expressing samples

# %%
dropSamples = list(QCDataDF[QCDataDF.columns[1:]].T[(QCDataDF[QCDataDF.columns[1:]]>threshold).sum(axis=0)/len(QCDataDF.index) < SamplePropCutOff].index)
print('dropSamples : ')
print(dropSamples)
QCDataDF = QCDataDF.drop(labels=dropSamples, axis=1)
# QCDataDF = QCDataDF.drop(index=dropSamples)
# QCDataDF
# Out:
# dropSamples :
# ['TMA_001_TNBC_240327a_006_Segment.1', 'TMA_001_TNBC_240327a_010_Segment.1', 'TMA_001_TNBC_240327a_018_Segment.1', 'TMA_001_TNBC_240327a_027_Segment.1', 'TMA_001_TNBC_240327a_042_Segment.1', 'TMA_001_TNBC_240327a_054_Segment.1']

# %% [markdown]
# - export data after dropping probes and samples due to low expression
# - re-run NSNorm
# - Continue with viewing data and QC of normalised data

# %%
# ToDo: Ask for project name interactively
project = configDict['projectName']

qcDropCSV = 'QC_' + project + '_RUV_Dropped.csv'

writeOutput = True
if writeOutput:
    QCDataDF.to_csv(os.path.join(normDir, qcDropCSV))
writeOutput= False

# %%
cmd = 'Rscript NSNorm.R -d ' + normDir + ' -s NSNormDropped -f ' + qcDropCSV
print(cmd)
os.system(cmd)
# Out:
# Rscript NSNorm.R -d /Users/upton6/Documents/Nanostring/projects/Adams/Normalisation -s NSNormDropped -f QC_Adams_Bray_RUV_Dropped.csv
# Loading required package: matrixStats
# Loading required package: ruv
# Loading required package: NanoStringNorm
# Loading required package: gdata
#
# Attaching package: ‘gdata’
#
# The following object is masked from ‘package:stats’:
#
#     nobs
#
# The following object is masked from ‘package:utils’:
#
#     object.size
#
# The following object is masked from ‘package:base’:
#
#     startsWith
#
# Loading required package: vsn
# Loading required package: Biobase
# Loading required package: BiocGenerics
#
# Attaching package: ‘BiocGenerics’
#
# The following object is masked from ‘package:gdata’:
#
#     combine
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, intersect, is.unsorted, lapply, Map, mapply,
#     match, mget, order, paste, pmax, pmax.int, pmin, pmin.int,
#     Position, rank, rbind, Reduce, rownames, sapply, setdiff, sort,
#     table, tapply, union, unique, unsplit, which.max, which.min
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attaching package: ‘Biobase’
#
# The following objects are masked from ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# Loading required package: XML
# Loading required package: data.table
#
# Attaching package: ‘data.table’
#
# The following objects are masked from ‘package:gdata’:
#
#     first, last
#
# Loading required package: NormqPCR
# Loading required package: RColorBrewer
# Loading required package: ReadqPCR
# Loading required package: qpcR
# Loading required package: MASS
# Loading required package: minpack.lm
# Loading required package: rgl
# Loading required package: robustbase
#
# Attaching package: ‘robustbase’
#
# The following object is masked from ‘package:Biobase’:
#
#     rowMedians
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colMedians, rowMedians
#
# Loading required package: Matrix
# Loading required package: optparse
# Loading required package: ComplexHeatmap
# Loading required package: grid
# ========================================
# ComplexHeatmap version 2.18.0
# Bioconductor page: http://bioconductor.org/packages/ComplexHeatmap/
# Github page: https://github.com/jokergoo/ComplexHeatmap
# Documentation: http://jokergoo.github.io/ComplexHeatmap-reference
#
# If you use it in published research, please cite either one:
# - Gu, Z. Complex Heatmap Visualization. iMeta 2022.
# - Gu, Z. Complex heatmaps reveal patterns and correlations in multidimensional
#     genomic data. Bioinformatics 2016.
#
#
# The new InteractiveComplexHeatmap package can directly export static
# complex heatmaps into an interactive Shiny app with zero effort. Have a try!
#
# This message can be suppressed by:
#   suppressPackageStartupMessages(library(ComplexHeatmap))
# ========================================
#
# Loading required package: dplyr
#
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:MASS’:
#
#     select
#
# The following objects are masked from ‘package:data.table’:
#
#     between, first, last
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, union
#
# The following objects are masked from ‘package:gdata’:
#
#     combine, first, last, starts_with
#
# The following object is masked from ‘package:matrixStats’:
#
#     count
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# Loading required package: plotrix
#
# Attaching package: ‘plotrix’
#
# The following object is masked from ‘package:rgl’:
#
#     mtext3d
#
# Loading required package: tuple
# Loading required package: scales
#
# Attaching package: ‘scales’
#
# The following object is masked from ‘package:plotrix’:
#
#     rescale
#
# Loading required package: ggplot2
# Loading required package: stringr
# [[1]]
# [1] TRUE
#
# [[2]]
# [1] TRUE
#
# [[3]]
# [1] TRUE
#
# [[4]]
# [1] TRUE
#
# [[5]]
# [1] TRUE
#
# [[6]]
# [1] TRUE
#
# [[7]]
# [1] TRUE
#
# [[8]]
# [1] TRUE
#
# [[9]]
# [1] TRUE
#
# [[10]]
# [1] TRUE
#
# [[11]]
# [1] TRUE
#
# [[12]]
# [1] TRUE
#
# [[13]]
# [1] TRUE
#
# [1] 67 92
# [1] 84  3
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 90 samples and 59
# 	Endogenous genes have less than 90% missing.
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 90 samples and 59
# 	Endogenous genes have less than 90% missing.
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 90 samples and 59
# 	Endogenous genes have less than 90% missing.
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 87 samples and 36
# 	Endogenous genes have less than 90% missing.
#
#                                    proportion.missing
# TMA_001_TNBC_240327a_015_Segment.1              0.915
# TMA_001_TNBC_240327a_048_Segment.1              0.915
# TMA_002_TNBC_240327_002_Segment.1               0.932
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 87 samples and 36
# 	Endogenous genes have less than 90% missing.
#
#                                    proportion.missing
# TMA_001_TNBC_240327a_015_Segment.1              0.915
# TMA_001_TNBC_240327a_048_Segment.1              0.915
# TMA_002_TNBC_240327_002_Segment.1               0.932
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 87 samples and 36
# 	Endogenous genes have less than 90% missing.
#
#                                    proportion.missing
# TMA_001_TNBC_240327a_015_Segment.1              0.915
# TMA_001_TNBC_240327a_048_Segment.1              0.915
# TMA_002_TNBC_240327_002_Segment.1               0.932
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 90 samples and 58
# 	Endogenous genes have less than 90% missing.
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 90 samples and 58
# 	Endogenous genes have less than 90% missing.
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 90 samples and 58
# 	Endogenous genes have less than 90% missing.
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 90 samples and 59
# 	Endogenous genes have less than 90% missing.
#
# SampleContent: The following samples have sample/rna content greater than
# 	3 standard deviations from the mean.
#
#                                    rna.zscore
# TMA_001_TNBC_240327a_050_Segment.1      -3.23
# TMA_002_TNBC_240327_004_Segment.1       -3.67
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 90 samples and 59
# 	Endogenous genes have less than 90% missing.
#
# SampleContent: The following samples have sample/rna content greater than
# 	3 standard deviations from the mean.
#
#                                    rna.zscore
# TMA_001_TNBC_240327a_050_Segment.1      -3.23
# TMA_002_TNBC_240327_004_Segment.1       -3.67
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 90 samples and 59
# 	Endogenous genes have less than 90% missing.
#
# SampleContent: The following samples have sample/rna content greater than
# 	3 standard deviations from the mean.
#
#                                    rna.zscore
# TMA_001_TNBC_240327a_050_Segment.1      -3.23
# TMA_002_TNBC_240327_004_Segment.1       -3.67
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 87 samples and 36
# 	Endogenous genes have less than 90% missing.
#
#                                    proportion.missing
# TMA_001_TNBC_240327a_015_Segment.1              0.915
# TMA_001_TNBC_240327a_048_Segment.1              0.915
# TMA_002_TNBC_240327_002_Segment.1               0.932
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 87 samples and 36
# 	Endogenous genes have less than 90% missing.
#
#                                    proportion.missing
# TMA_001_TNBC_240327a_015_Segment.1              0.915
# TMA_001_TNBC_240327a_048_Segment.1              0.915
# TMA_002_TNBC_240327_002_Segment.1               0.932
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 87 samples and 36
# 	Endogenous genes have less than 90% missing.
#
#                                    proportion.missing
# TMA_001_TNBC_240327a_015_Segment.1              0.915
# TMA_001_TNBC_240327a_048_Segment.1              0.915
# TMA_002_TNBC_240327_002_Segment.1               0.932
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 90 samples and 58
# 	Endogenous genes have less than 90% missing.
#
# SampleContent: The following samples have sample/rna content greater than
# 	3 standard deviations from the mean.
#
#                                    rna.zscore
# TMA_001_TNBC_240327a_050_Segment.1      -3.12
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 90 samples and 58
# 	Endogenous genes have less than 90% missing.
#
# SampleContent: The following samples have sample/rna content greater than
# 	3 standard deviations from the mean.
#
#                                    rna.zscore
# TMA_001_TNBC_240327a_050_Segment.1      -3.12
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 90 samples and 58
# 	Endogenous genes have less than 90% missing.
#
# SampleContent: The following samples have sample/rna content greater than
# 	3 standard deviations from the mean.
#
#                                    rna.zscore
# TMA_001_TNBC_240327a_050_Segment.1      -3.12
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 90 samples and 59
# 	Endogenous genes have less than 90% missing.
#
# SampleContent: The following samples have sample/rna content greater than
# 	3 standard deviations from the mean.
#
#                                    rna.zscore
# TMA_001_TNBC_240327a_050_Segment.1      -3.10
# TMA_002_TNBC_240327_004_Segment.1       -3.41
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 90 samples and 59
# 	Endogenous genes have less than 90% missing.
#
# SampleContent: The following samples have sample/rna content greater than
# 	3 standard deviations from the mean.
#
#                                    rna.zscore
# TMA_001_TNBC_240327a_050_Segment.1      -3.10
# TMA_002_TNBC_240327_004_Segment.1       -3.41
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 90 samples and 59
# 	Endogenous genes have less than 90% missing.
#
# SampleContent: The following samples have sample/rna content greater than
# 	3 standard deviations from the mean.
#
#                                    rna.zscore
# TMA_001_TNBC_240327a_050_Segment.1      -3.10
# TMA_002_TNBC_240327_004_Segment.1       -3.41
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 87 samples and 36
# 	Endogenous genes have less than 90% missing.
#
#                                    proportion.missing
# TMA_001_TNBC_240327a_015_Segment.1              0.915
# TMA_001_TNBC_240327a_048_Segment.1              0.915
# TMA_002_TNBC_240327_002_Segment.1               0.932
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 87 samples and 36
# 	Endogenous genes have less than 90% missing.
#
#                                    proportion.missing
# TMA_001_TNBC_240327a_015_Segment.1              0.915
# TMA_001_TNBC_240327a_048_Segment.1              0.915
# TMA_002_TNBC_240327_002_Segment.1               0.932
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 87 samples and 36
# 	Endogenous genes have less than 90% missing.
#
#                                    proportion.missing
# TMA_001_TNBC_240327a_015_Segment.1              0.915
# TMA_001_TNBC_240327a_048_Segment.1              0.915
# TMA_002_TNBC_240327_002_Segment.1               0.932
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 90 samples and 58
# 	Endogenous genes have less than 90% missing.
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 90 samples and 58
# 	Endogenous genes have less than 90% missing.
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 90 samples and 58
# 	Endogenous genes have less than 90% missing.
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# SampleContent: The following samples have sample/rna content greater than
# 	3 standard deviations from the mean.
#
#                                   rna.zscore
# TMA_002_TNBC_240327_028_Segment.1       3.05
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# SampleContent: The following samples have sample/rna content greater than
# 	3 standard deviations from the mean.
#
#                                   rna.zscore
# TMA_002_TNBC_240327_028_Segment.1       3.05
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# SampleContent: The following samples have sample/rna content greater than
# 	3 standard deviations from the mean.
#
#                                   rna.zscore
# TMA_002_TNBC_240327_028_Segment.1       3.05
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 90 samples and 59
# 	Endogenous genes have less than 90% missing.
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 90 samples and 59
# 	Endogenous genes have less than 90% missing.
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 90 samples and 59
# 	Endogenous genes have less than 90% missing.
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 87 samples and 36
# 	Endogenous genes have less than 90% missing.
#
#                                    proportion.missing
# TMA_001_TNBC_240327a_015_Segment.1              0.915
# TMA_001_TNBC_240327a_048_Segment.1              0.915
# TMA_002_TNBC_240327_002_Segment.1               0.932
#
# SampleContent: The following samples have sample/rna content greater than
# 	3 standard deviations from the mean.
#
#                                    rna.zscore
# TMA_001_TNBC_240327a_052_Segment.1       3.19
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 87 samples and 36
# 	Endogenous genes have less than 90% missing.
#
#                                    proportion.missing
# TMA_001_TNBC_240327a_015_Segment.1              0.915
# TMA_001_TNBC_240327a_048_Segment.1              0.915
# TMA_002_TNBC_240327_002_Segment.1               0.932
#
# SampleContent: The following samples have sample/rna content greater than
# 	3 standard deviations from the mean.
#
#                                    rna.zscore
# TMA_001_TNBC_240327a_052_Segment.1       3.19
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 87 samples and 36
# 	Endogenous genes have less than 90% missing.
#
#                                    proportion.missing
# TMA_001_TNBC_240327a_015_Segment.1              0.915
# TMA_001_TNBC_240327a_048_Segment.1              0.915
# TMA_002_TNBC_240327_002_Segment.1               0.932
#
# SampleContent: The following samples have sample/rna content greater than
# 	3 standard deviations from the mean.
#
#                                    rna.zscore
# TMA_001_TNBC_240327a_052_Segment.1       3.19
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 90 samples and 58
# 	Endogenous genes have less than 90% missing.
#
# SampleContent: The following samples have sample/rna content greater than
# 	3 standard deviations from the mean.
#
#                                    rna.zscore
# TMA_001_TNBC_240327a_052_Segment.1       3.07
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 90 samples and 58
# 	Endogenous genes have less than 90% missing.
#
# SampleContent: The following samples have sample/rna content greater than
# 	3 standard deviations from the mean.
#
#                                    rna.zscore
# TMA_001_TNBC_240327a_052_Segment.1       3.07
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 90 samples and 58
# 	Endogenous genes have less than 90% missing.
#
# SampleContent: The following samples have sample/rna content greater than
# 	3 standard deviations from the mean.
#
#                                    rna.zscore
# TMA_001_TNBC_240327a_052_Segment.1       3.07
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# SampleContent: The following genes have been chosen to adjust for RNA Content.
#
#    HK.Candidates
# 1             S6
# 2     Histone H3
# 3          GAPDH
# 4         HLA-DR
# 5          CTLA4
# 6            SMA
# 7           CD20
# 8          Ki-67
# 9            MET
# 10          PARP
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# SampleContent: The following genes have been chosen to adjust for RNA Content.
#
#    HK.Candidates
# 1             S6
# 2     Histone H3
# 3          GAPDH
# 4         HLA-DR
# 5          CTLA4
# 6            SMA
# 7           CD20
# 8          Ki-67
# 9            MET
# 10          PARP
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# SampleContent: The following genes have been chosen to adjust for RNA Content.
#
#    HK.Candidates
# 1             S6
# 2     Histone H3
# 3          GAPDH
# 4         HLA-DR
# 5          CTLA4
# 6            SMA
# 7           CD20
# 8          Ki-67
# 9            MET
# 10          PARP
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 90 samples and 59
# 	Endogenous genes have less than 90% missing.
#
# SampleContent: The following genes have been chosen to adjust for RNA Content.
#
#    HK.Candidates
# 1             S6
# 2     Histone H3
# 3          GAPDH
# 4          CTLA4
# 5            SMA
# 6           CD20
# 7          Ki-67
# 8            MET
# 9        Pan-AKT
# 10          PARP
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 90 samples and 59
# 	Endogenous genes have less than 90% missing.
#
# SampleContent: The following genes have been chosen to adjust for RNA Content.
#
#    HK.Candidates
# 1             S6
# 2     Histone H3
# 3          GAPDH
# 4         HLA-DR
# 5          CTLA4
# 6            SMA
# 7           CD20
# 8          Ki-67
# 9            MET
# 10          PARP
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 90 samples and 59
# 	Endogenous genes have less than 90% missing.
#
# SampleContent: The following genes have been chosen to adjust for RNA Content.
#
#    HK.Candidates
# 1             S6
# 2     Histone H3
# 3          GAPDH
# 4          CTLA4
# 5            SMA
# 6           CD20
# 7          Ki-67
# 8            MET
# 9        Pan-AKT
# 10          PARP
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 87 samples and 36
# 	Endogenous genes have less than 90% missing.
#
#                                    proportion.missing
# TMA_001_TNBC_240327a_015_Segment.1              0.915
# TMA_001_TNBC_240327a_048_Segment.1              0.915
# TMA_002_TNBC_240327_002_Segment.1               0.932
#
# SampleContent: The following genes have been chosen to adjust for RNA Content.
#
#    HK.Candidates
# 1             S6
# 2     Histone H3
# 3          GAPDH
# 4         HLA-DR
# 5          CTLA4
# 6            SMA
# 7          Ki-67
# 8         CD45RO
# 9        Pan-AKT
# 10          PARP
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 87 samples and 36
# 	Endogenous genes have less than 90% missing.
#
#                                    proportion.missing
# TMA_001_TNBC_240327a_015_Segment.1              0.915
# TMA_001_TNBC_240327a_048_Segment.1              0.915
# TMA_002_TNBC_240327_002_Segment.1               0.932
#
# SampleContent: The following genes have been chosen to adjust for RNA Content.
#
#    HK.Candidates
# 1             S6
# 2     Histone H3
# 3          GAPDH
# 4         HLA-DR
# 5          CTLA4
# 6            SMA
# 7          Ki-67
# 8         CD45RO
# 9        Pan-AKT
# 10          PARP
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 87 samples and 36
# 	Endogenous genes have less than 90% missing.
#
#                                    proportion.missing
# TMA_001_TNBC_240327a_015_Segment.1              0.915
# TMA_001_TNBC_240327a_048_Segment.1              0.915
# TMA_002_TNBC_240327_002_Segment.1               0.932
#
# SampleContent: The following genes have been chosen to adjust for RNA Content.
#
#    HK.Candidates
# 1             S6
# 2     Histone H3
# 3          GAPDH
# 4         HLA-DR
# 5          CTLA4
# 6            SMA
# 7          Ki-67
# 8         CD45RO
# 9        Pan-AKT
# 10          PARP
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 90 samples and 58
# 	Endogenous genes have less than 90% missing.
#
# SampleContent: The following genes have been chosen to adjust for RNA Content.
#
#    HK.Candidates
# 1             S6
# 2     Histone H3
# 3          GAPDH
# 4         HLA-DR
# 5          CTLA4
# 6            SMA
# 7          Ki-67
# 8            MET
# 9        Pan-AKT
# 10          PARP
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 90 samples and 58
# 	Endogenous genes have less than 90% missing.
#
# SampleContent: The following genes have been chosen to adjust for RNA Content.
#
#    HK.Candidates
# 1             S6
# 2     Histone H3
# 3          GAPDH
# 4         HLA-DR
# 5          CTLA4
# 6            SMA
# 7          Ki-67
# 8            MET
# 9        Pan-AKT
# 10          PARP
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 90 samples and 58
# 	Endogenous genes have less than 90% missing.
#
# SampleContent: The following genes have been chosen to adjust for RNA Content.
#
#    HK.Candidates
# 1             S6
# 2     Histone H3
# 3          GAPDH
# 4         HLA-DR
# 5          CTLA4
# 6            SMA
# 7          Ki-67
# 8            MET
# 9        Pan-AKT
# 10          PARP
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# SampleContent: The following samples have sample/rna content greater than
# 	3 standard deviations from the mean.
#
#                                   rna.zscore
# TMA_002_TNBC_240327_028_Segment.1       3.05
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# SampleContent: The following samples have sample/rna content greater than
# 	3 standard deviations from the mean.
#
#                                   rna.zscore
# TMA_002_TNBC_240327_028_Segment.1       3.05
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# SampleContent: The following samples have sample/rna content greater than
# 	3 standard deviations from the mean.
#
#                                   rna.zscore
# TMA_002_TNBC_240327_028_Segment.1       3.05
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 90 samples and 59
# 	Endogenous genes have less than 90% missing.
#
# SampleContent: The following samples have estimates of zero RNA content.  Consider removing them.
#
#  [1] "TMA_001_TNBC_240327a_003_Segment.1" "TMA_001_TNBC_240327a_009_Segment.1"
#  [3] "TMA_001_TNBC_240327a_014_Segment.1" "TMA_001_TNBC_240327a_015_Segment.1"
#  [5] "TMA_001_TNBC_240327a_017_Segment.1" "TMA_001_TNBC_240327a_026_Segment.1"
#  [7] "TMA_001_TNBC_240327a_038_Segment.1" "TMA_001_TNBC_240327a_043_Segment.1"
#  [9] "TMA_001_TNBC_240327a_048_Segment.1" "TMA_001_TNBC_240327a_050_Segment.1"
# [11] "TMA_001_TNBC_240327a_055_Segment.1" "TMA_002_TNBC_240327_003_Segment.1"
# [13] "TMA_002_TNBC_240327_004_Segment.1"  "TMA_002_TNBC_240327_016_Segment.1"
#
# SampleContent: The following samples have sample/rna content greater than
# 	3 standard deviations from the mean.
#
#                                    rna.zscore
# TMA_001_TNBC_240327a_052_Segment.1       3.03
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 90 samples and 59
# 	Endogenous genes have less than 90% missing.
#
# SampleContent: The following samples have estimates of zero RNA content.  Consider removing them.
#
#  [1] "TMA_001_TNBC_240327a_003_Segment.1" "TMA_001_TNBC_240327a_009_Segment.1"
#  [3] "TMA_001_TNBC_240327a_014_Segment.1" "TMA_001_TNBC_240327a_015_Segment.1"
#  [5] "TMA_001_TNBC_240327a_017_Segment.1" "TMA_001_TNBC_240327a_026_Segment.1"
#  [7] "TMA_001_TNBC_240327a_038_Segment.1" "TMA_001_TNBC_240327a_043_Segment.1"
#  [9] "TMA_001_TNBC_240327a_048_Segment.1" "TMA_001_TNBC_240327a_050_Segment.1"
# [11] "TMA_001_TNBC_240327a_055_Segment.1" "TMA_002_TNBC_240327_003_Segment.1"
# [13] "TMA_002_TNBC_240327_004_Segment.1"  "TMA_002_TNBC_240327_016_Segment.1"
#
# SampleContent: The following samples have sample/rna content greater than
# 	3 standard deviations from the mean.
#
#                                    rna.zscore
# TMA_001_TNBC_240327a_052_Segment.1       3.03
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 90 samples and 59
# 	Endogenous genes have less than 90% missing.
#
# SampleContent: The following samples have estimates of zero RNA content.  Consider removing them.
#
#  [1] "TMA_001_TNBC_240327a_003_Segment.1" "TMA_001_TNBC_240327a_009_Segment.1"
#  [3] "TMA_001_TNBC_240327a_014_Segment.1" "TMA_001_TNBC_240327a_015_Segment.1"
#  [5] "TMA_001_TNBC_240327a_017_Segment.1" "TMA_001_TNBC_240327a_026_Segment.1"
#  [7] "TMA_001_TNBC_240327a_038_Segment.1" "TMA_001_TNBC_240327a_043_Segment.1"
#  [9] "TMA_001_TNBC_240327a_048_Segment.1" "TMA_001_TNBC_240327a_050_Segment.1"
# [11] "TMA_001_TNBC_240327a_055_Segment.1" "TMA_002_TNBC_240327_003_Segment.1"
# [13] "TMA_002_TNBC_240327_004_Segment.1"  "TMA_002_TNBC_240327_016_Segment.1"
#
# SampleContent: The following samples have sample/rna content greater than
# 	3 standard deviations from the mean.
#
#                                    rna.zscore
# TMA_001_TNBC_240327a_052_Segment.1       3.03
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 87 samples and 36
# 	Endogenous genes have less than 90% missing.
#
#                                    proportion.missing
# TMA_001_TNBC_240327a_015_Segment.1              0.915
# TMA_001_TNBC_240327a_048_Segment.1              0.915
# TMA_002_TNBC_240327_002_Segment.1               0.932
#
# SampleContent: The following samples have estimates of zero RNA content.  Consider removing them.
#
#  [1] "TMA_001_TNBC_240327a_001_Segment.1" "TMA_001_TNBC_240327a_002_Segment.1"
#  [3] "TMA_001_TNBC_240327a_003_Segment.1" "TMA_001_TNBC_240327a_004_Segment.1"
#  [5] "TMA_001_TNBC_240327a_005_Segment.1" "TMA_001_TNBC_240327a_007_Segment.1"
#  [7] "TMA_001_TNBC_240327a_008_Segment.1" "TMA_001_TNBC_240327a_009_Segment.1"
#  [9] "TMA_001_TNBC_240327a_011_Segment.1" "TMA_001_TNBC_240327a_012_Segment.1"
# [11] "TMA_001_TNBC_240327a_013_Segment.1" "TMA_001_TNBC_240327a_014_Segment.1"
# [13] "TMA_001_TNBC_240327a_015_Segment.1" "TMA_001_TNBC_240327a_016_Segment.1"
# [15] "TMA_001_TNBC_240327a_017_Segment.1" "TMA_001_TNBC_240327a_019_Segment.1"
# [17] "TMA_001_TNBC_240327a_020_Segment.1" "TMA_001_TNBC_240327a_021_Segment.1"
# [19] "TMA_001_TNBC_240327a_022_Segment.1" "TMA_001_TNBC_240327a_023_Segment.1"
# [21] "TMA_001_TNBC_240327a_024_Segment.1" "TMA_001_TNBC_240327a_025_Segment.1"
# [23] "TMA_001_TNBC_240327a_026_Segment.1" "TMA_001_TNBC_240327a_028_Segment.1"
# [25] "TMA_001_TNBC_240327a_029_Segment.1" "TMA_001_TNBC_240327a_030_Segment.1"
# [27] "TMA_001_TNBC_240327a_031_Segment.1" "TMA_001_TNBC_240327a_032_Segment.1"
# [29] "TMA_001_TNBC_240327a_033_Segment.1" "TMA_001_TNBC_240327a_034_Segment.1"
# [31] "TMA_001_TNBC_240327a_035_Segment.1" "TMA_001_TNBC_240327a_036_Segment.1"
# [33] "TMA_001_TNBC_240327a_037_Segment.1" "TMA_001_TNBC_240327a_038_Segment.1"
# [35] "TMA_001_TNBC_240327a_039_Segment.1" "TMA_001_TNBC_240327a_040_Segment.1"
# [37] "TMA_001_TNBC_240327a_041_Segment.1" "TMA_001_TNBC_240327a_043_Segment.1"
# [39] "TMA_001_TNBC_240327a_044_Segment.1" "TMA_001_TNBC_240327a_045_Segment.1"
# [41] "TMA_001_TNBC_240327a_046_Segment.1" "TMA_001_TNBC_240327a_047_Segment.1"
# [43] "TMA_001_TNBC_240327a_048_Segment.1" "TMA_001_TNBC_240327a_049_Segment.1"
# [45] "TMA_001_TNBC_240327a_050_Segment.1" "TMA_001_TNBC_240327a_051_Segment.1"
# [47] "TMA_001_TNBC_240327a_053_Segment.1" "TMA_001_TNBC_240327a_055_Segment.1"
# [49] "TMA_001_TNBC_240327a_056_Segment.1" "TMA_001_TNBC_240327a_057_Segment.1"
# [51] "TMA_001_TNBC_240327a_058_Segment.1" "TMA_002_TNBC_240327_001_Segment.1"
# [53] "TMA_002_TNBC_240327_002_Segment.1"  "TMA_002_TNBC_240327_003_Segment.1"
# [55] "TMA_002_TNBC_240327_004_Segment.1"  "TMA_002_TNBC_240327_005_Segment.1"
# [57] "TMA_002_TNBC_240327_006_Segment.1"  "TMA_002_TNBC_240327_007_Segment.1"
# [59] "TMA_002_TNBC_240327_008_Segment.1"  "TMA_002_TNBC_240327_009_Segment.1"
# [61] "TMA_002_TNBC_240327_010_Segment.1"  "TMA_002_TNBC_240327_011_Segment.1"
# [63] "TMA_002_TNBC_240327_012_Segment.1"  "TMA_002_TNBC_240327_013_Segment.1"
# [65] "TMA_002_TNBC_240327_014_Segment.1"  "TMA_002_TNBC_240327_015_Segment.1"
# [67] "TMA_002_TNBC_240327_016_Segment.1"  "TMA_002_TNBC_240327_017_Segment.1"
# [69] "TMA_002_TNBC_240327_018_Segment.1"  "TMA_002_TNBC_240327_019_Segment.1"
# [71] "TMA_002_TNBC_240327_020_Segment.1"  "TMA_002_TNBC_240327_021_Segment.1"
# [73] "TMA_002_TNBC_240327_022_Segment.1"  "TMA_002_TNBC_240327_023_Segment.1"
# [75] "TMA_002_TNBC_240327_024_Segment.1"  "TMA_002_TNBC_240327_025_Segment.1"
# [77] "TMA_002_TNBC_240327_026_Segment.1"  "TMA_002_TNBC_240327_027_Segment.1"
# [79] "TMA_002_TNBC_240327_028_Segment.1"  "TMA_002_TNBC_240327_029_Segment.1"
# [81] "TMA_002_TNBC_240327_030_Segment.1"  "TMA_002_TNBC_240327_031_Segment.1"
# [83] "TMA_002_TNBC_240327_032_Segment.1"  "TMA_002_TNBC_240327_034_Segment.1"
# [85] "TMA_002_TNBC_240327_035_Segment.1"  "TMA_002_TNBC_240327_036_Segment.1"
# [87] "TMA_002_TNBC_240327_037_Segment.1"  "TMA_002_TNBC_240327_038_Segment.1"
#
# SampleContent: The following samples have sample/rna content greater than
# 	3 standard deviations from the mean.
#
#                                    rna.zscore
# TMA_001_TNBC_240327a_052_Segment.1       9.11
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 87 samples and 36
# 	Endogenous genes have less than 90% missing.
#
#                                    proportion.missing
# TMA_001_TNBC_240327a_015_Segment.1              0.915
# TMA_001_TNBC_240327a_048_Segment.1              0.915
# TMA_002_TNBC_240327_002_Segment.1               0.932
#
# SampleContent: The following samples have estimates of zero RNA content.  Consider removing them.
#
#  [1] "TMA_001_TNBC_240327a_001_Segment.1" "TMA_001_TNBC_240327a_002_Segment.1"
#  [3] "TMA_001_TNBC_240327a_003_Segment.1" "TMA_001_TNBC_240327a_004_Segment.1"
#  [5] "TMA_001_TNBC_240327a_005_Segment.1" "TMA_001_TNBC_240327a_007_Segment.1"
#  [7] "TMA_001_TNBC_240327a_008_Segment.1" "TMA_001_TNBC_240327a_009_Segment.1"
#  [9] "TMA_001_TNBC_240327a_011_Segment.1" "TMA_001_TNBC_240327a_012_Segment.1"
# [11] "TMA_001_TNBC_240327a_013_Segment.1" "TMA_001_TNBC_240327a_014_Segment.1"
# [13] "TMA_001_TNBC_240327a_015_Segment.1" "TMA_001_TNBC_240327a_016_Segment.1"
# [15] "TMA_001_TNBC_240327a_017_Segment.1" "TMA_001_TNBC_240327a_019_Segment.1"
# [17] "TMA_001_TNBC_240327a_020_Segment.1" "TMA_001_TNBC_240327a_021_Segment.1"
# [19] "TMA_001_TNBC_240327a_022_Segment.1" "TMA_001_TNBC_240327a_023_Segment.1"
# [21] "TMA_001_TNBC_240327a_024_Segment.1" "TMA_001_TNBC_240327a_025_Segment.1"
# [23] "TMA_001_TNBC_240327a_026_Segment.1" "TMA_001_TNBC_240327a_028_Segment.1"
# [25] "TMA_001_TNBC_240327a_029_Segment.1" "TMA_001_TNBC_240327a_030_Segment.1"
# [27] "TMA_001_TNBC_240327a_031_Segment.1" "TMA_001_TNBC_240327a_032_Segment.1"
# [29] "TMA_001_TNBC_240327a_033_Segment.1" "TMA_001_TNBC_240327a_034_Segment.1"
# [31] "TMA_001_TNBC_240327a_035_Segment.1" "TMA_001_TNBC_240327a_036_Segment.1"
# [33] "TMA_001_TNBC_240327a_037_Segment.1" "TMA_001_TNBC_240327a_038_Segment.1"
# [35] "TMA_001_TNBC_240327a_039_Segment.1" "TMA_001_TNBC_240327a_040_Segment.1"
# [37] "TMA_001_TNBC_240327a_041_Segment.1" "TMA_001_TNBC_240327a_043_Segment.1"
# [39] "TMA_001_TNBC_240327a_044_Segment.1" "TMA_001_TNBC_240327a_045_Segment.1"
# [41] "TMA_001_TNBC_240327a_046_Segment.1" "TMA_001_TNBC_240327a_047_Segment.1"
# [43] "TMA_001_TNBC_240327a_048_Segment.1" "TMA_001_TNBC_240327a_049_Segment.1"
# [45] "TMA_001_TNBC_240327a_050_Segment.1" "TMA_001_TNBC_240327a_051_Segment.1"
# [47] "TMA_001_TNBC_240327a_053_Segment.1" "TMA_001_TNBC_240327a_055_Segment.1"
# [49] "TMA_001_TNBC_240327a_056_Segment.1" "TMA_001_TNBC_240327a_057_Segment.1"
# [51] "TMA_001_TNBC_240327a_058_Segment.1" "TMA_002_TNBC_240327_001_Segment.1"
# [53] "TMA_002_TNBC_240327_002_Segment.1"  "TMA_002_TNBC_240327_003_Segment.1"
# [55] "TMA_002_TNBC_240327_004_Segment.1"  "TMA_002_TNBC_240327_005_Segment.1"
# [57] "TMA_002_TNBC_240327_006_Segment.1"  "TMA_002_TNBC_240327_007_Segment.1"
# [59] "TMA_002_TNBC_240327_008_Segment.1"  "TMA_002_TNBC_240327_009_Segment.1"
# [61] "TMA_002_TNBC_240327_010_Segment.1"  "TMA_002_TNBC_240327_011_Segment.1"
# [63] "TMA_002_TNBC_240327_012_Segment.1"  "TMA_002_TNBC_240327_013_Segment.1"
# [65] "TMA_002_TNBC_240327_014_Segment.1"  "TMA_002_TNBC_240327_015_Segment.1"
# [67] "TMA_002_TNBC_240327_016_Segment.1"  "TMA_002_TNBC_240327_017_Segment.1"
# [69] "TMA_002_TNBC_240327_018_Segment.1"  "TMA_002_TNBC_240327_019_Segment.1"
# [71] "TMA_002_TNBC_240327_020_Segment.1"  "TMA_002_TNBC_240327_021_Segment.1"
# [73] "TMA_002_TNBC_240327_022_Segment.1"  "TMA_002_TNBC_240327_023_Segment.1"
# [75] "TMA_002_TNBC_240327_024_Segment.1"  "TMA_002_TNBC_240327_025_Segment.1"
# [77] "TMA_002_TNBC_240327_026_Segment.1"  "TMA_002_TNBC_240327_027_Segment.1"
# [79] "TMA_002_TNBC_240327_028_Segment.1"  "TMA_002_TNBC_240327_029_Segment.1"
# [81] "TMA_002_TNBC_240327_030_Segment.1"  "TMA_002_TNBC_240327_031_Segment.1"
# [83] "TMA_002_TNBC_240327_032_Segment.1"  "TMA_002_TNBC_240327_034_Segment.1"
# [85] "TMA_002_TNBC_240327_035_Segment.1"  "TMA_002_TNBC_240327_036_Segment.1"
# [87] "TMA_002_TNBC_240327_037_Segment.1"  "TMA_002_TNBC_240327_038_Segment.1"
#
# SampleContent: The following samples have sample/rna content greater than
# 	3 standard deviations from the mean.
#
#                                    rna.zscore
# TMA_001_TNBC_240327a_052_Segment.1       9.11
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 87 samples and 36
# 	Endogenous genes have less than 90% missing.
#
#                                    proportion.missing
# TMA_001_TNBC_240327a_015_Segment.1              0.915
# TMA_001_TNBC_240327a_048_Segment.1              0.915
# TMA_002_TNBC_240327_002_Segment.1               0.932
#
# SampleContent: The following samples have estimates of zero RNA content.  Consider removing them.
#
#  [1] "TMA_001_TNBC_240327a_001_Segment.1" "TMA_001_TNBC_240327a_002_Segment.1"
#  [3] "TMA_001_TNBC_240327a_003_Segment.1" "TMA_001_TNBC_240327a_004_Segment.1"
#  [5] "TMA_001_TNBC_240327a_005_Segment.1" "TMA_001_TNBC_240327a_007_Segment.1"
#  [7] "TMA_001_TNBC_240327a_008_Segment.1" "TMA_001_TNBC_240327a_009_Segment.1"
#  [9] "TMA_001_TNBC_240327a_011_Segment.1" "TMA_001_TNBC_240327a_012_Segment.1"
# [11] "TMA_001_TNBC_240327a_013_Segment.1" "TMA_001_TNBC_240327a_014_Segment.1"
# [13] "TMA_001_TNBC_240327a_015_Segment.1" "TMA_001_TNBC_240327a_016_Segment.1"
# [15] "TMA_001_TNBC_240327a_017_Segment.1" "TMA_001_TNBC_240327a_019_Segment.1"
# [17] "TMA_001_TNBC_240327a_020_Segment.1" "TMA_001_TNBC_240327a_021_Segment.1"
# [19] "TMA_001_TNBC_240327a_022_Segment.1" "TMA_001_TNBC_240327a_023_Segment.1"
# [21] "TMA_001_TNBC_240327a_024_Segment.1" "TMA_001_TNBC_240327a_025_Segment.1"
# [23] "TMA_001_TNBC_240327a_026_Segment.1" "TMA_001_TNBC_240327a_028_Segment.1"
# [25] "TMA_001_TNBC_240327a_029_Segment.1" "TMA_001_TNBC_240327a_030_Segment.1"
# [27] "TMA_001_TNBC_240327a_031_Segment.1" "TMA_001_TNBC_240327a_032_Segment.1"
# [29] "TMA_001_TNBC_240327a_033_Segment.1" "TMA_001_TNBC_240327a_034_Segment.1"
# [31] "TMA_001_TNBC_240327a_035_Segment.1" "TMA_001_TNBC_240327a_036_Segment.1"
# [33] "TMA_001_TNBC_240327a_037_Segment.1" "TMA_001_TNBC_240327a_038_Segment.1"
# [35] "TMA_001_TNBC_240327a_039_Segment.1" "TMA_001_TNBC_240327a_040_Segment.1"
# [37] "TMA_001_TNBC_240327a_041_Segment.1" "TMA_001_TNBC_240327a_043_Segment.1"
# [39] "TMA_001_TNBC_240327a_044_Segment.1" "TMA_001_TNBC_240327a_045_Segment.1"
# [41] "TMA_001_TNBC_240327a_046_Segment.1" "TMA_001_TNBC_240327a_047_Segment.1"
# [43] "TMA_001_TNBC_240327a_048_Segment.1" "TMA_001_TNBC_240327a_049_Segment.1"
# [45] "TMA_001_TNBC_240327a_050_Segment.1" "TMA_001_TNBC_240327a_051_Segment.1"
# [47] "TMA_001_TNBC_240327a_053_Segment.1" "TMA_001_TNBC_240327a_055_Segment.1"
# [49] "TMA_001_TNBC_240327a_056_Segment.1" "TMA_001_TNBC_240327a_057_Segment.1"
# [51] "TMA_001_TNBC_240327a_058_Segment.1" "TMA_002_TNBC_240327_001_Segment.1"
# [53] "TMA_002_TNBC_240327_002_Segment.1"  "TMA_002_TNBC_240327_003_Segment.1"
# [55] "TMA_002_TNBC_240327_004_Segment.1"  "TMA_002_TNBC_240327_005_Segment.1"
# [57] "TMA_002_TNBC_240327_006_Segment.1"  "TMA_002_TNBC_240327_007_Segment.1"
# [59] "TMA_002_TNBC_240327_008_Segment.1"  "TMA_002_TNBC_240327_009_Segment.1"
# [61] "TMA_002_TNBC_240327_010_Segment.1"  "TMA_002_TNBC_240327_011_Segment.1"
# [63] "TMA_002_TNBC_240327_012_Segment.1"  "TMA_002_TNBC_240327_013_Segment.1"
# [65] "TMA_002_TNBC_240327_014_Segment.1"  "TMA_002_TNBC_240327_015_Segment.1"
# [67] "TMA_002_TNBC_240327_016_Segment.1"  "TMA_002_TNBC_240327_017_Segment.1"
# [69] "TMA_002_TNBC_240327_018_Segment.1"  "TMA_002_TNBC_240327_019_Segment.1"
# [71] "TMA_002_TNBC_240327_020_Segment.1"  "TMA_002_TNBC_240327_021_Segment.1"
# [73] "TMA_002_TNBC_240327_022_Segment.1"  "TMA_002_TNBC_240327_023_Segment.1"
# [75] "TMA_002_TNBC_240327_024_Segment.1"  "TMA_002_TNBC_240327_025_Segment.1"
# [77] "TMA_002_TNBC_240327_026_Segment.1"  "TMA_002_TNBC_240327_027_Segment.1"
# [79] "TMA_002_TNBC_240327_028_Segment.1"  "TMA_002_TNBC_240327_029_Segment.1"
# [81] "TMA_002_TNBC_240327_030_Segment.1"  "TMA_002_TNBC_240327_031_Segment.1"
# [83] "TMA_002_TNBC_240327_032_Segment.1"  "TMA_002_TNBC_240327_034_Segment.1"
# [85] "TMA_002_TNBC_240327_035_Segment.1"  "TMA_002_TNBC_240327_036_Segment.1"
# [87] "TMA_002_TNBC_240327_037_Segment.1"  "TMA_002_TNBC_240327_038_Segment.1"
#
# SampleContent: The following samples have sample/rna content greater than
# 	3 standard deviations from the mean.
#
#                                    rna.zscore
# TMA_001_TNBC_240327a_052_Segment.1       9.11
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 90 samples and 58
# 	Endogenous genes have less than 90% missing.
#
# SampleContent: The following samples have estimates of zero RNA content.  Consider removing them.
#
#  [1] "TMA_001_TNBC_240327a_001_Segment.1" "TMA_001_TNBC_240327a_002_Segment.1"
#  [3] "TMA_001_TNBC_240327a_003_Segment.1" "TMA_001_TNBC_240327a_004_Segment.1"
#  [5] "TMA_001_TNBC_240327a_007_Segment.1" "TMA_001_TNBC_240327a_008_Segment.1"
#  [7] "TMA_001_TNBC_240327a_009_Segment.1" "TMA_001_TNBC_240327a_011_Segment.1"
#  [9] "TMA_001_TNBC_240327a_012_Segment.1" "TMA_001_TNBC_240327a_013_Segment.1"
# [11] "TMA_001_TNBC_240327a_014_Segment.1" "TMA_001_TNBC_240327a_015_Segment.1"
# [13] "TMA_001_TNBC_240327a_016_Segment.1" "TMA_001_TNBC_240327a_017_Segment.1"
# [15] "TMA_001_TNBC_240327a_020_Segment.1" "TMA_001_TNBC_240327a_021_Segment.1"
# [17] "TMA_001_TNBC_240327a_022_Segment.1" "TMA_001_TNBC_240327a_023_Segment.1"
# [19] "TMA_001_TNBC_240327a_024_Segment.1" "TMA_001_TNBC_240327a_025_Segment.1"
# [21] "TMA_001_TNBC_240327a_026_Segment.1" "TMA_001_TNBC_240327a_028_Segment.1"
# [23] "TMA_001_TNBC_240327a_029_Segment.1" "TMA_001_TNBC_240327a_030_Segment.1"
# [25] "TMA_001_TNBC_240327a_031_Segment.1" "TMA_001_TNBC_240327a_032_Segment.1"
# [27] "TMA_001_TNBC_240327a_034_Segment.1" "TMA_001_TNBC_240327a_035_Segment.1"
# [29] "TMA_001_TNBC_240327a_036_Segment.1" "TMA_001_TNBC_240327a_037_Segment.1"
# [31] "TMA_001_TNBC_240327a_038_Segment.1" "TMA_001_TNBC_240327a_039_Segment.1"
# [33] "TMA_001_TNBC_240327a_040_Segment.1" "TMA_001_TNBC_240327a_041_Segment.1"
# [35] "TMA_001_TNBC_240327a_043_Segment.1" "TMA_001_TNBC_240327a_045_Segment.1"
# [37] "TMA_001_TNBC_240327a_046_Segment.1" "TMA_001_TNBC_240327a_047_Segment.1"
# [39] "TMA_001_TNBC_240327a_048_Segment.1" "TMA_001_TNBC_240327a_049_Segment.1"
# [41] "TMA_001_TNBC_240327a_050_Segment.1" "TMA_001_TNBC_240327a_051_Segment.1"
# [43] "TMA_001_TNBC_240327a_053_Segment.1" "TMA_001_TNBC_240327a_055_Segment.1"
# [45] "TMA_001_TNBC_240327a_057_Segment.1" "TMA_001_TNBC_240327a_058_Segment.1"
# [47] "TMA_002_TNBC_240327_001_Segment.1"  "TMA_002_TNBC_240327_002_Segment.1"
# [49] "TMA_002_TNBC_240327_003_Segment.1"  "TMA_002_TNBC_240327_004_Segment.1"
# [51] "TMA_002_TNBC_240327_005_Segment.1"  "TMA_002_TNBC_240327_007_Segment.1"
# [53] "TMA_002_TNBC_240327_012_Segment.1"  "TMA_002_TNBC_240327_013_Segment.1"
# [55] "TMA_002_TNBC_240327_015_Segment.1"  "TMA_002_TNBC_240327_016_Segment.1"
# [57] "TMA_002_TNBC_240327_017_Segment.1"  "TMA_002_TNBC_240327_018_Segment.1"
# [59] "TMA_002_TNBC_240327_020_Segment.1"  "TMA_002_TNBC_240327_025_Segment.1"
# [61] "TMA_002_TNBC_240327_034_Segment.1"  "TMA_002_TNBC_240327_035_Segment.1"
# [63] "TMA_002_TNBC_240327_036_Segment.1"  "TMA_002_TNBC_240327_037_Segment.1"
# [65] "TMA_002_TNBC_240327_038_Segment.1"
#
# SampleContent: The following samples have sample/rna content greater than
# 	3 standard deviations from the mean.
#
#                                    rna.zscore
# TMA_001_TNBC_240327a_052_Segment.1       5.53
# TMA_002_TNBC_240327_019_Segment.1        3.68
# TMA_002_TNBC_240327_022_Segment.1        3.73
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 90 samples and 58
# 	Endogenous genes have less than 90% missing.
#
# SampleContent: The following samples have estimates of zero RNA content.  Consider removing them.
#
#  [1] "TMA_001_TNBC_240327a_001_Segment.1" "TMA_001_TNBC_240327a_002_Segment.1"
#  [3] "TMA_001_TNBC_240327a_003_Segment.1" "TMA_001_TNBC_240327a_004_Segment.1"
#  [5] "TMA_001_TNBC_240327a_007_Segment.1" "TMA_001_TNBC_240327a_008_Segment.1"
#  [7] "TMA_001_TNBC_240327a_009_Segment.1" "TMA_001_TNBC_240327a_011_Segment.1"
#  [9] "TMA_001_TNBC_240327a_012_Segment.1" "TMA_001_TNBC_240327a_013_Segment.1"
# [11] "TMA_001_TNBC_240327a_014_Segment.1" "TMA_001_TNBC_240327a_015_Segment.1"
# [13] "TMA_001_TNBC_240327a_016_Segment.1" "TMA_001_TNBC_240327a_017_Segment.1"
# [15] "TMA_001_TNBC_240327a_020_Segment.1" "TMA_001_TNBC_240327a_021_Segment.1"
# [17] "TMA_001_TNBC_240327a_022_Segment.1" "TMA_001_TNBC_240327a_023_Segment.1"
# [19] "TMA_001_TNBC_240327a_024_Segment.1" "TMA_001_TNBC_240327a_025_Segment.1"
# [21] "TMA_001_TNBC_240327a_026_Segment.1" "TMA_001_TNBC_240327a_028_Segment.1"
# [23] "TMA_001_TNBC_240327a_029_Segment.1" "TMA_001_TNBC_240327a_030_Segment.1"
# [25] "TMA_001_TNBC_240327a_031_Segment.1" "TMA_001_TNBC_240327a_032_Segment.1"
# [27] "TMA_001_TNBC_240327a_034_Segment.1" "TMA_001_TNBC_240327a_035_Segment.1"
# [29] "TMA_001_TNBC_240327a_036_Segment.1" "TMA_001_TNBC_240327a_037_Segment.1"
# [31] "TMA_001_TNBC_240327a_038_Segment.1" "TMA_001_TNBC_240327a_039_Segment.1"
# [33] "TMA_001_TNBC_240327a_040_Segment.1" "TMA_001_TNBC_240327a_041_Segment.1"
# [35] "TMA_001_TNBC_240327a_043_Segment.1" "TMA_001_TNBC_240327a_045_Segment.1"
# [37] "TMA_001_TNBC_240327a_046_Segment.1" "TMA_001_TNBC_240327a_047_Segment.1"
# [39] "TMA_001_TNBC_240327a_048_Segment.1" "TMA_001_TNBC_240327a_049_Segment.1"
# [41] "TMA_001_TNBC_240327a_050_Segment.1" "TMA_001_TNBC_240327a_051_Segment.1"
# [43] "TMA_001_TNBC_240327a_053_Segment.1" "TMA_001_TNBC_240327a_055_Segment.1"
# [45] "TMA_001_TNBC_240327a_057_Segment.1" "TMA_001_TNBC_240327a_058_Segment.1"
# [47] "TMA_002_TNBC_240327_001_Segment.1"  "TMA_002_TNBC_240327_002_Segment.1"
# [49] "TMA_002_TNBC_240327_003_Segment.1"  "TMA_002_TNBC_240327_004_Segment.1"
# [51] "TMA_002_TNBC_240327_005_Segment.1"  "TMA_002_TNBC_240327_007_Segment.1"
# [53] "TMA_002_TNBC_240327_012_Segment.1"  "TMA_002_TNBC_240327_013_Segment.1"
# [55] "TMA_002_TNBC_240327_015_Segment.1"  "TMA_002_TNBC_240327_016_Segment.1"
# [57] "TMA_002_TNBC_240327_017_Segment.1"  "TMA_002_TNBC_240327_018_Segment.1"
# [59] "TMA_002_TNBC_240327_020_Segment.1"  "TMA_002_TNBC_240327_025_Segment.1"
# [61] "TMA_002_TNBC_240327_034_Segment.1"  "TMA_002_TNBC_240327_035_Segment.1"
# [63] "TMA_002_TNBC_240327_036_Segment.1"  "TMA_002_TNBC_240327_037_Segment.1"
# [65] "TMA_002_TNBC_240327_038_Segment.1"
#
# SampleContent: The following samples have sample/rna content greater than
# 	3 standard deviations from the mean.
#
#                                    rna.zscore
# TMA_001_TNBC_240327a_052_Segment.1       5.53
# TMA_002_TNBC_240327_019_Segment.1        3.68
# TMA_002_TNBC_240327_022_Segment.1        3.73
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 90 samples and 58
# 	Endogenous genes have less than 90% missing.
#
# SampleContent: The following samples have estimates of zero RNA content.  Consider removing them.
#
#  [1] "TMA_001_TNBC_240327a_001_Segment.1" "TMA_001_TNBC_240327a_002_Segment.1"
#  [3] "TMA_001_TNBC_240327a_003_Segment.1" "TMA_001_TNBC_240327a_004_Segment.1"
#  [5] "TMA_001_TNBC_240327a_007_Segment.1" "TMA_001_TNBC_240327a_008_Segment.1"
#  [7] "TMA_001_TNBC_240327a_009_Segment.1" "TMA_001_TNBC_240327a_011_Segment.1"
#  [9] "TMA_001_TNBC_240327a_012_Segment.1" "TMA_001_TNBC_240327a_013_Segment.1"
# [11] "TMA_001_TNBC_240327a_014_Segment.1" "TMA_001_TNBC_240327a_015_Segment.1"
# [13] "TMA_001_TNBC_240327a_016_Segment.1" "TMA_001_TNBC_240327a_017_Segment.1"
# [15] "TMA_001_TNBC_240327a_020_Segment.1" "TMA_001_TNBC_240327a_021_Segment.1"
# [17] "TMA_001_TNBC_240327a_022_Segment.1" "TMA_001_TNBC_240327a_023_Segment.1"
# [19] "TMA_001_TNBC_240327a_024_Segment.1" "TMA_001_TNBC_240327a_025_Segment.1"
# [21] "TMA_001_TNBC_240327a_026_Segment.1" "TMA_001_TNBC_240327a_028_Segment.1"
# [23] "TMA_001_TNBC_240327a_029_Segment.1" "TMA_001_TNBC_240327a_030_Segment.1"
# [25] "TMA_001_TNBC_240327a_031_Segment.1" "TMA_001_TNBC_240327a_032_Segment.1"
# [27] "TMA_001_TNBC_240327a_034_Segment.1" "TMA_001_TNBC_240327a_035_Segment.1"
# [29] "TMA_001_TNBC_240327a_036_Segment.1" "TMA_001_TNBC_240327a_037_Segment.1"
# [31] "TMA_001_TNBC_240327a_038_Segment.1" "TMA_001_TNBC_240327a_039_Segment.1"
# [33] "TMA_001_TNBC_240327a_040_Segment.1" "TMA_001_TNBC_240327a_041_Segment.1"
# [35] "TMA_001_TNBC_240327a_043_Segment.1" "TMA_001_TNBC_240327a_045_Segment.1"
# [37] "TMA_001_TNBC_240327a_046_Segment.1" "TMA_001_TNBC_240327a_047_Segment.1"
# [39] "TMA_001_TNBC_240327a_048_Segment.1" "TMA_001_TNBC_240327a_049_Segment.1"
# [41] "TMA_001_TNBC_240327a_050_Segment.1" "TMA_001_TNBC_240327a_051_Segment.1"
# [43] "TMA_001_TNBC_240327a_053_Segment.1" "TMA_001_TNBC_240327a_055_Segment.1"
# [45] "TMA_001_TNBC_240327a_057_Segment.1" "TMA_001_TNBC_240327a_058_Segment.1"
# [47] "TMA_002_TNBC_240327_001_Segment.1"  "TMA_002_TNBC_240327_002_Segment.1"
# [49] "TMA_002_TNBC_240327_003_Segment.1"  "TMA_002_TNBC_240327_004_Segment.1"
# [51] "TMA_002_TNBC_240327_005_Segment.1"  "TMA_002_TNBC_240327_007_Segment.1"
# [53] "TMA_002_TNBC_240327_012_Segment.1"  "TMA_002_TNBC_240327_013_Segment.1"
# [55] "TMA_002_TNBC_240327_015_Segment.1"  "TMA_002_TNBC_240327_016_Segment.1"
# [57] "TMA_002_TNBC_240327_017_Segment.1"  "TMA_002_TNBC_240327_018_Segment.1"
# [59] "TMA_002_TNBC_240327_020_Segment.1"  "TMA_002_TNBC_240327_025_Segment.1"
# [61] "TMA_002_TNBC_240327_034_Segment.1"  "TMA_002_TNBC_240327_035_Segment.1"
# [63] "TMA_002_TNBC_240327_036_Segment.1"  "TMA_002_TNBC_240327_037_Segment.1"
# [65] "TMA_002_TNBC_240327_038_Segment.1"
#
# SampleContent: The following samples have sample/rna content greater than
# 	3 standard deviations from the mean.
#
#                                    rna.zscore
# TMA_001_TNBC_240327a_052_Segment.1       5.53
# TMA_002_TNBC_240327_019_Segment.1        3.68
# TMA_002_TNBC_240327_022_Segment.1        3.73
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# SampleContent: The following samples have sample/rna content greater than
# 	3 standard deviations from the mean.
#
#                                   rna.zscore
# TMA_002_TNBC_240327_028_Segment.1        3.2
# 0

# %%
files = os.listdir(os.path.join(normDir, 'NSNormDropped'))
files = sorted(files)

# %%
width = 6
height = 14

fig, axs = plt.subplots(height, width, figsize=[40,25])
# fig.suptitle('Nanostring Normalisation heatmaps')
for y in range(height):
    for x in range(width):
        fileIdx = x + y*width
        tempDF = pd.read_csv(os.path.join(normDir, 'NSNorm',files[fileIdx]), index_col=0)
#         axs[y][x].matshow(np.log2(tempDF + 1), aspect = 'auto', cmap='coolwarm')
        axs[y][x].matshow(np.log2(tempDF.loc[probeOrder,sampleOrder] + 1), cmap='coolwarm')
        axs[y][x].set_xticks([])
        axs[y][x].set_yticks([])
        axs[y][x].set_title(files[fileIdx][:-4])
    
# plt.tight_layout()
# fig.show()
fig.savefig('NSNormDropped.png')
# Out:
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# SampleContent: The following samples have sample/rna content greater than
# 	3 standard deviations from the mean.
#
#                                   rna.zscore
# TMA_002_TNBC_240327_028_Segment.1        3.2
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# SampleContent: The following samples have sample/rna content greater than
# 	3 standard deviations from the mean.
#
#                                   rna.zscore
# TMA_002_TNBC_240327_028_Segment.1        3.2
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 90 samples and 59
# 	Endogenous genes have less than 90% missing.
#
# SampleContent: The following samples have sample/rna content greater than
# 	3 standard deviations from the mean.
#
#                                    rna.zscore
# TMA_001_TNBC_240327a_052_Segment.1       3.39
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 90 samples and 59
# 	Endogenous genes have less than 90% missing.
#
# SampleContent: The following samples have sample/rna content greater than
# 	3 standard deviations from the mean.
#
#                                    rna.zscore
# TMA_001_TNBC_240327a_052_Segment.1       3.39
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 90 samples and 59
# 	Endogenous genes have less than 90% missing.
#
# SampleContent: The following samples have sample/rna content greater than
# 	3 standard deviations from the mean.
#
#                                    rna.zscore
# TMA_001_TNBC_240327a_052_Segment.1       3.39
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 87 samples and 36
# 	Endogenous genes have less than 90% missing.
#
#                                    proportion.missing
# TMA_001_TNBC_240327a_015_Segment.1              0.915
# TMA_001_TNBC_240327a_048_Segment.1              0.915
# TMA_002_TNBC_240327_002_Segment.1               0.932
#
# SampleContent: The following samples have sample/rna content greater than
# 	3 standard deviations from the mean.
#
#                                    rna.zscore
# TMA_001_TNBC_240327a_052_Segment.1       3.64
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 87 samples and 36
# 	Endogenous genes have less than 90% missing.
#
#                                    proportion.missing
# TMA_001_TNBC_240327a_015_Segment.1              0.915
# TMA_001_TNBC_240327a_048_Segment.1              0.915
# TMA_002_TNBC_240327_002_Segment.1               0.932
#
# SampleContent: The following samples have sample/rna content greater than
# 	3 standard deviations from the mean.
#
#                                    rna.zscore
# TMA_001_TNBC_240327a_052_Segment.1       3.64
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 87 samples and 36
# 	Endogenous genes have less than 90% missing.
#
#                                    proportion.missing
# TMA_001_TNBC_240327a_015_Segment.1              0.915
# TMA_001_TNBC_240327a_048_Segment.1              0.915
# TMA_002_TNBC_240327_002_Segment.1               0.932
#
# SampleContent: The following samples have sample/rna content greater than
# 	3 standard deviations from the mean.
#
#                                    rna.zscore
# TMA_001_TNBC_240327a_052_Segment.1       3.64
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 90 samples and 58
# 	Endogenous genes have less than 90% missing.
#
# SampleContent: The following samples have sample/rna content greater than
# 	3 standard deviations from the mean.
#
#                                    rna.zscore
# TMA_001_TNBC_240327a_052_Segment.1       3.65
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 90 samples and 58
# 	Endogenous genes have less than 90% missing.
#
# SampleContent: The following samples have sample/rna content greater than
# 	3 standard deviations from the mean.
#
#                                    rna.zscore
# TMA_001_TNBC_240327a_052_Segment.1       3.65
#
#
# ##############################
# ### NanoStringNorm v1.2.1.1 ###
# ##############################
#
# There are 90 samples and 59 Endogenous genes
#
# Background: After correction 90 samples and 58
# 	Endogenous genes have less than 90% missing.
#
# SampleContent: The following samples have sample/rna content greater than
# 	3 standard deviations from the mean.
#
#                                    rna.zscore
# TMA_001_TNBC_240327a_052_Segment.1       3.65

# %% [markdown]
# # working

# %%
# Drop samples from sample info file

# %%
# generate groups for EdgeR analysis

# %%
# temp = noneMeanHKDF > 0

# %%
# noneMeanHKDF = pd.read_csv(os.path.join(normDir, 'NSNorm',files[27]), index_col=0)
noneMeanHKDF = pd.read_csv(os.path.join(normDir, 'NSNormDropped',files[27]), index_col=0)

# %%
# noneMeanHKDF

# %%
# groupedExpressedIndex = noneMeanHKDF.loc[probeOrder].loc[((noneMeanHKDF > 0 ).sum(axis = 1) / len(noneMeanHKDF.columns) > 0.33333)].index

# %%
# groupedExpressedIndex

# %%
# len(groupedExpressedIndex)

# %%
QCData = pd.read_csv(os.path.join(normDir, QCDataFile), index_col=0)

QCData
# Out:
#                    Code.Class  TMA_001_TNBC_240327a_001_Segment 1  \
# Name
# HYB-POS              Positive                           12.625935
# HYB-NEG              Negative                            0.000000
# Rb IgG               Negative                            1.045593
# Ms IgG2a             Negative                            2.627672
# Ms IgG1              Negative                            2.720807
# ...                       ...                                 ...
# PARP               Endogenous                            7.106187
# p53                Endogenous                            6.377961
# Neurofibromin      Endogenous                            2.146914
# GZMA               Endogenous                            2.338343
# Cleaved Caspase 9  Endogenous                            3.225564
#
#                    TMA_001_TNBC_240327a_002_Segment 1  \
# Name
# HYB-POS                                     12.625935
# HYB-NEG                                      2.793596
# Rb IgG                                       2.793596
# Ms IgG2a                                     3.808274
# Ms IgG1                                      2.793596
# ...                                               ...
# PARP                                         7.812480
# p53                                          4.628279
# Neurofibromin                                2.793596
# GZMA                                         3.945611
# Cleaved Caspase 9                            3.931844
#
#                    TMA_001_TNBC_240327a_003_Segment 1  \
# Name
# HYB-POS                                     12.625935
# HYB-NEG                                      0.000000
# Rb IgG                                       1.066650
# Ms IgG2a                                     2.132914
# Ms IgG1                                      2.331394
# ...                                               ...
# PARP                                         3.566884
# p53                                          5.677989
# Neurofibromin                                1.501747
# GZMA                                         2.556847
# Cleaved Caspase 9                            1.503189
#
#                    TMA_001_TNBC_240327a_004_Segment 1  \
# Name
# HYB-POS                                     12.625935
# HYB-NEG                                      1.004169
# Rb IgG                                       0.557196
# Ms IgG2a                                     3.146628
# Ms IgG1                                      2.736299
# ...                                               ...
# PARP                                         6.889795
# p53                                          8.754944
# Neurofibromin                                3.184298
# GZMA                                         2.675566
# Cleaved Caspase 9                            2.653086
#
#                    TMA_001_TNBC_240327a_005_Segment 1  \
# Name
# HYB-POS                                     12.625935
# HYB-NEG                                      0.314395
# Rb IgG                                       1.516725
# Ms IgG2a                                     2.510311
# Ms IgG1                                      2.631488
# ...                                               ...
# PARP                                         6.865160
# p53                                          3.272861
# Neurofibromin                                3.628637
# GZMA                                         2.373308
# Cleaved Caspase 9                            2.351216
#
#                    TMA_001_TNBC_240327a_006_Segment 1  \
# Name
# HYB-POS                                     12.625935
# HYB-NEG                                      0.000000
# Rb IgG                                       1.135462
# Ms IgG2a                                     2.342814
# Ms IgG1                                      2.860733
# ...                                               ...
# PARP                                         2.012114
# p53                                          0.000000
# Neurofibromin                                0.000000
# GZMA                                         1.149487
# Cleaved Caspase 9                            0.000000
#
#                    TMA_001_TNBC_240327a_007_Segment 1  \
# Name
# HYB-POS                                     12.625935
# HYB-NEG                                      0.000000
# Rb IgG                                       1.477035
# Ms IgG2a                                     0.725550
# Ms IgG1                                      3.027965
# ...                                               ...
# PARP                                         5.660780
# p53                                          6.667540
# Neurofibromin                                2.578355
# GZMA                                         1.495158
# Cleaved Caspase 9                            1.913573
#
#                    TMA_001_TNBC_240327a_008_Segment 1  \
# Name
# HYB-POS                                     12.625935
# HYB-NEG                                      0.000000
# Rb IgG                                       1.436052
# Ms IgG2a                                     2.695478
# Ms IgG1                                      1.867320
# ...                                               ...
# PARP                                         4.496040
# p53                                          4.581192
# Neurofibromin                                1.557066
# GZMA                                         2.728802
# Cleaved Caspase 9                            1.872591
#
#                    TMA_001_TNBC_240327a_009_Segment 1  ...  \
# Name                                                   ...
# HYB-POS                                     12.625935  ...
# HYB-NEG                                      0.000000  ...
# Rb IgG                                       0.823522  ...
# Ms IgG2a                                     1.290032  ...
# Ms IgG1                                      2.548793  ...
# ...                                               ...  ...
# PARP                                         3.610621  ...
# p53                                          2.657333  ...
# Neurofibromin                                1.170651  ...
# GZMA                                         0.837547  ...
# Cleaved Caspase 9                            0.823780  ...
#
#                    TMA_002_TNBC_240327_029_Segment 1  \
# Name
# HYB-POS                                    12.625935
# HYB-NEG                                     1.122351
# Rb IgG                                      2.255253
# Ms IgG2a                                    1.554131
# Ms IgG1                                     0.950091
# ...                                              ...
# PARP                                        4.915751
# p53                                         1.862821
# Neurofibromin                               2.680527
# GZMA                                        1.407218
# Cleaved Caspase 9                           1.111766
#
#                    TMA_002_TNBC_240327_030_Segment 1  \
# Name
# HYB-POS                                    12.625935
# HYB-NEG                                     0.000000
# Rb IgG                                      2.496249
# Ms IgG2a                                    1.604406
# Ms IgG1                                     2.169513
# ...                                              ...
# PARP                                        5.146283
# p53                                         3.292147
# Neurofibromin                               3.790071
# GZMA                                        1.770312
# Cleaved Caspase 9                           3.158052
#
#                    TMA_002_TNBC_240327_031_Segment 1  \
# Name
# HYB-POS                                    12.625935
# HYB-NEG                                     0.633711
# Rb IgG                                      1.555716
# Ms IgG2a                                    2.460184
# Ms IgG1                                     2.569061
# ...                                              ...
# PARP                                        5.689139
# p53                                         2.807529
# Neurofibromin                               1.797846
# GZMA                                        1.503541
# Cleaved Caspase 9                           2.205431
#
#                    TMA_002_TNBC_240327_032_Segment 1  \
# Name
# HYB-POS                                    12.625935
# HYB-NEG                                     0.000000
# Rb IgG                                      1.036810
# Ms IgG2a                                    2.124519
# Ms IgG1                                     1.887186
# ...                                              ...
# PARP                                        6.383030
# p53                                         4.612679
# Neurofibromin                               2.664105
# GZMA                                        2.535272
# Cleaved Caspase 9                           2.314698
#
#                    TMA_002_TNBC_240327_033_Segment 1  \
# Name
# HYB-POS                                    12.625935
# HYB-NEG                                     1.516337
# Rb IgG                                      2.429410
# Ms IgG2a                                    1.948116
# Ms IgG1                                     2.043978
# ...                                              ...
# PARP                                        5.883092
# p53                                         3.520352
# Neurofibromin                               3.553885
# GZMA                                        3.853519
# Cleaved Caspase 9                           2.503095
#
#                    TMA_002_TNBC_240327_034_Segment 1  \
# Name
# HYB-POS                                    12.625935
# HYB-NEG                                     0.000000
# Rb IgG                                      2.412331
# Ms IgG2a                                    1.514150
# Ms IgG1                                     0.787067
# ...                                              ...
# PARP                                        4.930855
# p53                                         3.918402
# Neurofibromin                               2.334499
# GZMA                                        2.761242
# Cleaved Caspase 9                           3.070091
#
#                    TMA_002_TNBC_240327_035_Segment 1  \
# Name
# HYB-POS                                    12.625935
# HYB-NEG                                     1.006545
# Rb IgG                                      2.724411
# Ms IgG2a                                    1.606399
# Ms IgG1                                     2.588394
# ...                                              ...
# PARP                                        6.249396
# p53                                         3.010378
# Neurofibromin                               2.170679
# GZMA                                        1.876375
# Cleaved Caspase 9                           2.992638
#
#                    TMA_002_TNBC_240327_036_Segment 1  \
# Name
# HYB-POS                                    12.625935
# HYB-NEG                                     1.173610
# Rb IgG                                      2.412190
# Ms IgG2a                                    1.184794
# Ms IgG1                                     2.943010
# ...                                              ...
# PARP                                        4.647429
# p53                                         3.347428
# Neurofibromin                               1.628305
# GZMA                                        1.643459
# Cleaved Caspase 9                           2.161697
#
#                    TMA_002_TNBC_240327_037_Segment 1  \
# Name
# HYB-POS                                    12.625935
# HYB-NEG                                     0.000000
# Rb IgG                                      1.713695
# Ms IgG2a                                    0.000000
# Ms IgG1                                     2.157911
# ...                                              ...
# PARP                                        5.000464
# p53                                         3.117560
# Neurofibromin                               2.934829
# GZMA                                        0.706228
# Cleaved Caspase 9                           1.779778
#
#                    TMA_002_TNBC_240327_038_Segment 1
# Name
# HYB-POS                                    12.625935
# HYB-NEG                                     0.000000
# Rb IgG                                      1.759730
# Ms IgG2a                                    1.854467
# Ms IgG1                                     1.950329
# ...                                              ...
# PARP                                        4.426636
# p53                                         2.841559
# Neurofibromin                               2.831209
# GZMA                                        1.707556
# Cleaved Caspase 9                           0.829795
#
# [79 rows x 97 columns]

# %% [markdown]
# # Run EdgeR analysis

# %% [markdown]
# Write comparisons to a text file that will be parsed by the r script
#
# In form of factor.variable, factor.variable2, comparisonName
# 1 comparison per line

# %% [markdown]
#   make_option(c("-d", "--datadir"), type="character", default=NULL,
#               help="dataset file name", metavar="character"),
#   make_option(c("-f", "--file"), type="character", default=NULL,
#               help="dataset file name", metavar="character"),
#   make_option(c("-e", "--exportdir"), type="character", default="NSNorm",
#               help="dataset file name", metavar="character"),
#   make_option(c("-i", "--sampleinfo"), type="character", default=NULL,
#               help="dataset file name", metavar="character")

# %% [markdown]
# ### extract potential factors for analysis from info file

# %%
groups = ['Broad_classification']

# %%
# ['Sample_Type', 'Patient', 'Broad_classification']

# %% [markdown]
# ### extract potential groups based on factors

# %% [markdown]
# ### Show group numbers for each of the comparisons

# %%
# comps = [
#     [
#         'Hydrogel - Spheroid'
#     ],
#     [
#         'Hydrogel.BDNF - Hydrogel.SD',
#         'Hydrogel.Dream - Hydrogel.SD',
#         'Hydrogel.PDGF - Hydrogel.SD',
#         'Spheroid.Hep - Spheroid.SD'    
#     ],
#     [
#         'Hydrogel.SD.Outer - Hydrogel.SD.Inner',
#         'Hydrogel.BDNF.Outer - Hydrogel.BDNF.Inner',
#         'Hydrogel.Dream.Outer - Hydrogel.Dream.Inner',
#         'Hydrogel.PDGF.Outer - Hydrogel.PDGF.Inner',
#         'Spheroid.SD.Outer - Spheroid.SD.Inner',
#         'Spheroid.Hep.Outer - Spheroid.Hep.Inner'
#     ],
# ]

# compNames = []
# for g in comps:
#     ctemp = []
#     for c in g:
#         c = c.replace('.','_')
#         c = c.replace(' - ','_vs_')
#         ctemp.append(c)
#     compNames.append(ctemp)
    

# compNames

# %%
comps = [
    [
        'Secondary - Primary'
    ]
]

compNames = []
for g in comps:
    ctemp = []
    for c in g:
        c = c.replace('.','_')
        c = c.replace(' - ','_vs_')
        ctemp.append(c)
    compNames.append(ctemp)
    

compNames
# Out:
# [['Secondary_vs_Primary']]

# %%
# configDict['rootDir']

# %%
normPath = os.path.join('Normalisation','NSNormDropped')
print(normPath)

normFile = 'NanoStringNorm_49_none_none_low.cv.geo.mean.csv'
print(normFile)

exportdir = 'EdgeR'
runname = 'Default'
sampleinfoFile = 'sampleInfo_with_Wells.csv'
# Out:
# Normalisation/NSNormDropped
# NanoStringNorm_49_none_none_low.cv.geo.mean.csv

# %% [markdown]
# ### Set up config file for EdgeR

# %%
os.getcwd()
# Out:
# '/Users/upton6/Library/CloudStorage/OneDrive-QueenslandUniversityofTechnology/Documents/notebooks/Nanostring/Adams_Bray/DSP_EDA_Protein'

# %%
outFile = 'EdgeR_Config.txt'

outLines = []
for g in range(len(groups)):
    groupLine = 'GROUP:' + groups[g]
    outLines.append(groupLine)
    
    compLine = 'COMPARISON:'
    compNameLine = 'COMP_NAME:'
    for c in range(len(comps[g])):
        compLine += comps[g][c]
        compLine += ','
        compNameLine += compNames[g][c]
        compNameLine += ','
    
    outLines.append(compLine)
    outLines.append(compNameLine)

with open(outFile, 'w') as o:
    o.write('\n'.join(outLines))
    o.write('\n')

# %%
## Need to handle dropped samples that may still be present in sampleinfoFile. Could be handled with another file, or by removing samples within R.

# %%
cmd = 'Rscript EdgeR.R -c ' + os.getcwd() + ' -d ' + configDict['rootDir'] + ' -n ' + normPath + ' -f ' + normFile + ' -e ' + exportdir + ' -r ' + runname  + ' -i ' + sampleinfoFile
print(cmd)
os.system(cmd)
# Out:
# Rscript EdgeR.R -c /Users/upton6/Library/CloudStorage/OneDrive-QueenslandUniversityofTechnology/Documents/notebooks/Nanostring/Adams_Bray/DSP_EDA_Protein -d /Users/upton6/Documents/Nanostring/projects/Adams/ -n Normalisation/NSNormDropped -f NanoStringNorm_49_none_none_low.cv.geo.mean.csv -e EdgeR -r Default -i sampleInfo_with_Wells.csv
# [1] "Checking libraries:"
# Loading required package: edgeR
# Loading required package: limma
# [[1]]
# [1] TRUE
#
# [[2]]
# [1] TRUE
#
# [[3]]
# [1] TRUE
#
# [1] "If any values above are FALSE, library availability must be checked"
# [1] " "
# [1] "groups"
# [[1]]
# [1] "Broad_classification"
#
# [1] "/Users/upton6/Documents/Nanostring/projects/Adams/"
# [1] "/Users/upton6/Documents/Nanostring/projects/Adams//Normalisation/NSNormDropped/NanoStringNorm_49_none_none_low.cv.geo.mean.csv"
# [1] "Normalisation/NSNormDropped"
# [[1]]
# [1] "Broad_classification"
# Loading required package: optparse
# Loading required package: stringr
# Error in DGEList.default(counts = counts, lib.size = lib.size, norm.factors = norm.factors,  :
#   Length of 'group' must equal number of columns in 'counts'
# Calls: setup_y ... DGEList -> DGEList.data.frame -> DGEList -> DGEList.default
# Execution halted
# 256

# %% [markdown]
# # Convert MD Plots to Volcano Plots

# %%
# Currently done in a separate notebook

# %%
break
# Out:
#   Cell In[56], line 1
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
# dataPath = '../../../Nanostring/projects/.../DSP_Protein_Data/'
dataPath = configDict['rootDir']
data = pd.read_csv(os.path.join(dataPath,'HK_Geo_Mean_Normalised.csv'), index_col = 0)
probeFilter = pd.read_csv(os.path.join(dataPath,'Probe_Filter.csv'), index_col = 0)
sampleInfo = pd.read_csv(os.path.join(dataPath,'Sample_Info.csv'), index_col = 0)

# dataPath = '../../../Nanostring/projects/.../EdgeR/EdgeR_normData.tsv'
dataPath = os.path.join(configDict['rootDir'], normPath, normFile)

data = pd.read_csv(dataPath, index_col = 0)

# dataPath = '../../../Nanostring/projects/.../DSP_Protein_Data/'
dataPath = configDict['rootDir']

# %%
data

# %%
sampleInfo.columns

# %%
wb = load_workbook(os.path.join(dataPath,'Annotation template file-1a_wells_02.xlsx'))

print(wb.sheetnames)

# %%
ws = wb['Annotation template']

segments = [[y.value for y in x] for x in ws[ws.calculate_dimension()]]
df = pd.DataFrame(segments)


rowLabels = df.iloc[1:,0]
colLabels = df.iloc[0,1:]
annotations = df.iloc[1:,1:]
rowLabels += '_'
rowLabels += df.iloc[1:,1]
rowLabels += '_Full ROI'

# %%
rowLabels

# %%
colLabels

# %%
annotations.values

# %%
sampleAnnotations = pd.DataFrame(annotations.values, index=rowLabels, columns=colLabels)

# sampleAnnotations = sampleAnnotations.T
# sampleAnnotations.set_index(0, drop=True, inplace=True)
# sampleAnnotations = sampleAnnotations.T
# sampleAnnotations.set_index('Scan name', drop=True, inplace=True)
# sampleAnnotations = sampleAnnotations.T

# %%
sampleAnnotations

# %%
sampleAnnotations = sampleAnnotations.join(sampleInfo.T,lsuffix='Drop').T

# %%
sampleAnnotations.drop(labels=[x for x in sampleAnnotations.index if x.endswith('Drop')], inplace=True)

# %%
sampleInfo = sampleAnnotations

# %%
sampleInfo

# %%
def standardize_data(arr):
         
    '''
    This function standardize an array, its substracts mean value, 
    and then divide the standard deviation.
    
    param 1: array 
    return: standardized array
    '''    
    rows, columns = arr.shape
    
    standardizedArray = np.zeros(shape=(rows, columns))
    tempArray = np.zeros(rows)
    
    for column in range(columns):
        
        mean = np.mean(X[:,column])
        std = np.std(X[:,column])
        tempArray = np.empty(0)
        
        for element in X[:,column]:
            
            tempArray = np.append(tempArray, ((element - mean) / std))
 
        standardizedArray[:,column] = tempArray
    
    return standardizedArray

# %%
# Standardizing data

### I'm not sure that the transpose is what i want here. The data is the wrong shape and pc's seems to be being calculated for proteins instead of samples
X = endogNorm.transpose().values
# X = endogNorm.values
### Try to get pc's for samples
# X = endogNorm.values

## ??? With transpose makes PCA for effect of variables on smaples, without makes PCA for effects of variables on protein expression levels
###^^^ Maybe the other way round?



X_cols = endogNorm.columns
print(X_cols.shape)
y = endogNorm.index
print(y.shape)
X = standardize_data(X)
print(X.shape)

# %%
# Calculating the covariance matrix

covariance_matrix = np.cov(X.T)
# covariance_matrix = np.cov(X)



print(covariance_matrix.shape)

# %%
# Using np.linalg.eig function

eigen_values, eigen_vectors = np.linalg.eig(covariance_matrix)
print("Eigenvector: \n",eigen_vectors,"\n")
print("Eigenvalues: \n", eigen_values, "\n")
print(eigen_vectors.shape)

# %%
eigenDF = pd.DataFrame(eigen_vectors, index=[endogNorm.index], columns=[endogNorm.index])
# eigenDF = pd.DataFrame(eigen_vectors, index=[endogNorm.columns], columns=[endogNorm.columns])

# %%
# Calculating the explained variance on each of components


variance_explained = []
for i in eigen_values:
     variance_explained.append((i/sum(eigen_values))*100)
        
print(variance_explained)

# %%
# Identifying components that explain at least 95%

cumulative_variance_explained = np.cumsum(variance_explained)
print(cumulative_variance_explained)

# %%
cumulative_variance_explained = [np.float64(x) for x in cumulative_variance_explained]

# %%
cumulative_variance_explained[0].dtype

# %%
# Visualizing the eigenvalues and finding the "elbow" in the graphic


sns.lineplot(x = [i for i in range(len(cumulative_variance_explained))], y=cumulative_variance_explained)
# plt.xlabel("Number of components")
# plt.ylabel("Cumulative explained variance")
# plt.title("Explained variance vs Number of components")



# ToDo:
# Add lines for 95% variance, and number of components describing at least 95% of variance

# %%
# Using two first components (because those explain more than 95%)

projection_matrix = (eigen_vectors.T[:][:50]).T
print(projection_matrix)

# %%
colours = ['g' if x.split('_')[-1] == 'Tumour' else 'r' for x in X_cols]
colours = ['g' if x.split('_')[-1] == 'Tumour' else 'r' if x.split('_')[-1] == 'Immune' else 'purple' for x in X_cols]

# %%
# I dont think this gives relevant info. projection matrix needs to be combined with original data to see effects of components on patients

plt.scatter([x[0] for x in projection_matrix], [x[1] for x in projection_matrix])#, c=colours)

projection_matrix.shape

# %%
plt.scatter([x[2] for x in projection_matrix], [x[1] for x in projection_matrix])#, c=colours)

# %%
plt.scatter([x[2] for x in projection_matrix], [x[3] for x in projection_matrix])#, c=colours)

# %%
# Getting the product of original standardized X and the eigenvectors 


X_pca = X.dot(projection_matrix)
print(X_pca)

# %%
X_pca.shape

# %%
sampleInfo

# %%
# tagDF = pd.DataFrame( data=[x.split(',') for x in sampleInfo.loc['Segment tags']], index=sampleInfo.columns, columns=['Obese','Arth','Patellar'])

# %%
# tagDF

# %%
# sampleInfo = pd.concat([sampleInfo,tagDF.T])

# %%
sampleInfo

# %%
inforSortedIndex = sampleInfo.sort_values(by=['Obese','arthritis','TMA_Core'], axis=1).columns

# %%
### Add umap / tSNE analysis here
